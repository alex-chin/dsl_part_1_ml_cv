# %% [markdown]
# ![dls.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h1 style="text-align: center;"><b>Домашнее задание. Решение конкурса на kaggle</b></h1>

# %% [markdown]
# Это домашнее задание посвящено полноценному решению задачи машинного обучения.

# %% [markdown]
# Есть две части этого домашнего задания:
#
# ### Отправить ваши предсказания в Stepik.
# За прохождение определенных порогов будут начисляться баллы. Эта часть оценивается из 5 баллов.
#
# 1) $1.00 \geqslant score \geqslant 0.84$ --- 5 баллов
#
# 2) $0.84 > score \geqslant 0.77$ --- 4 балла
#
# 3) $0.77 > score \geqslant 0.70$ --- 3 балла
#
# 4) $0.70 > score \geqslant 0.65$ --- 2 балла
#
# 5) $0.65 > score \geqslant 0.6$ --- 1 балл
#
# 6) $0.60 > score$ --- 0 баллов
#
# Для этого мы предварительно разделили данные в задании на две части.
# * `train.csv`. На этом наборе данных вам необходимо создать и обучить модель. Подробное описание файла есть в ноутбуке.
# * `test.csv`. В каждой строчке файла `test.csv` указаны признаки тестовых объектов. Предсказания для этого набора необходимо записать в файл submission.csv и сдать в соответствующий шаг на Stepik. Количество попыток ограничено 100 штук.
#
# Отправлять в Stepik вы будете файл с ответами `my_submission.csv`. В этом файле вам необходимо для каждого объекта из датасета предсказать вероятность класса 1. Мы подготовили для вас файл с примером посылки `submission.csv`. Ваш файл должен быть оформлен таким же образом. В ноутбуке есть пример оформления файла посылки. Для отправки файла с предсказаниями на Stepik есть отдельный шаг.
#
# ### Сделать полноценный отчет о вашей работе.
# Опишите, как вы обработали данные, какие модели попробовали и какие результаты получились (максимум 10 баллов). За каждую выполненную часть будет начислено определенное количество баллов. В этом пункте вам необходимо отправить файл в формате .ipynb на Stepik --- для этого в домашнем задании есть отдельный шаг. Этот пункт оценивается из 10 баллов.
#
# **Вторая часть будет проверяться в формате peer-review. Т.е. вашу посылку на Stepik будут проверять 3 других студента, и медианное значение их оценок будет выставлено. Чтобы получить баллы, вам также нужно будет проверить трех других учеников. Это станет доступно после того, как вы сдадите задание сами.**
#
# ### Контест на Kaggle
# Для вашего удобства мы подготовили [контест на Kaggle](https://www.kaggle.com/c/advanced-dls-spring-2021/). Тестирующая система на Kaggle выдает те же баллы, что и Stepik. Мы рекомендуем в качестве основной тестирующей системы использовать именно Kaggle, а затем сдать лучшую посылку на Stepik. Так вы привыкните работать с Kaggle.
#
# Проблема для российских пользователей Kaggle заключается в том, что подтверждение аккаунта по номеру телефона работает с перебоями или не работает вообще. Без подтвержденного номера телефона вы не сможете совершать посылки в kaggle. Если у вас возникла такая проблема, мы советуем следующие шаги:
# * Попробовать зарегистрировать аккаунт с аутентификацией через gmail. В таком случае, аккаунт должен работать без подтверждения номера телефона.
# * Если у вас есть не российский номер, используйте его для верификации аккаунта.
# * Если на номер телефона не приходит смс для верификации аккаунта, обратитесь в службу поддержки kaggle. Они с переменным успехом умеют подтверждать аккаунты вручную.
# * Если все же подтвердить аккаунт и получить доступ к сдаче заданий не удалось, используйте только сдачу в Stepik.
#
# ### Несколько замечаний по выполнению работы
# * Во всех пунктах указания это минимальный набор вещей, которые стоит сделать. Если вы можете сделать какой-то шаг лучше или добавить что-то свое --- дерзайте!
# * Пожалуйста, перед сдачей ноутбука убедитесь, что работа чистая и понятная. Это значительно облегчит проверку и повысит ваши ожидаемые баллы.
# * Если у вас будут проблемы с решением или хочется совета, то пишите в наш чат в телеграме.
#
#
# Данные: [train.csv](https://drive.google.com/file/d/1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K/view?usp=share_link),
# [test.csv](https://drive.google.com/file/d/1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r/view?usp=share_link), [submission.csv](https://drive.google.com/file/d/199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y/view?usp=share_link).
#
# Если ссылки на данные не работают, их можно скачать [на Kaggle](https://www.kaggle.com/competitions/advanced-dls-spring-2021/data).

# %% [markdown]
# # Как проверять?
#
# Ставьте полный балл, если выполнены все рекомендации или сделано что-то более интересное и сложное. За каждый отсустствующий пункт из рекомендации снижайте 1 балл.
#
# **Если решение верное, но не удовлетворяет вашим эстетическим предпочтениям, за это баллы снижать не нужно.**

# %% [markdown]
# # Метрика
#
# Перед решением любой задачи важно понимать, как будет оцениваться ваше решение. В данном случае мы используем стандартную для задачи классификации метрику ROC-AUC. Ее можно вычислить, используя только предсказанные вероятности и истинные классы без конкретного порога классификации + она раотает даже если классы в данных сильно несбалансированны (примеров одного класса в десятки раз больше примеров длугого). Именно поэтому она очень удобна для соревнований.
#
# Посчитать ее легко:

# %%
from sklearn.metrics import roc_auc_score

y_true = [
    0,
    1,
    1,
    0,
    1
]

y_predictions = [
    0.1,
    0.9,
    0.4,
    0.6,
    0.61
]

roc_auc_score(y_true, y_predictions)
# Out:
# 0.8333333333333333

# %% [markdown]
# # Первая часть. Исследование

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Загрузка данных (2 балла)
#
# 1) Посмотрите на случайные строчки.
#
# 2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо, если вы построите табличку с количеством nan в каждой колонке.

# %%
# !gdown 1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K  # train.csv
# !gdown 1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r  # test.csv
# !gdown 199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y  # submission.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K
# To: /content/train.csv
# 100% 664k/664k [00:00<00:00, 3.87MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r
# To: /content/test.csv
# 100% 218k/218k [00:00<00:00, 56.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y
# To: /content/submission.csv
# 100% 14.7k/14.7k [00:00<00:00, 30.7MB/s]

# %%
data = pd.read_csv('./train.csv')

# %%
# Для вашего удобства списки с именами разных колонок

# Числовые признаки
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

# Категориальные признаки
cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols
target_col = 'Churn'

# %%
data.sample(5)
# Out:
#       ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 623             56            59.80    3457.45    Male                0
# 2069            10            74.75     799.65  Female                0
# 4955            10           110.10     1043.3    Male                0
# 4789            72            89.80    6510.45  Female                0
# 2329             5            20.25      109.8    Male                0
#
#      HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 623         Yes      Yes             Yes                      No
# 2069         No       No             Yes                     Yes
# 4955         No       No             Yes                      No
# 4789        Yes      Yes             Yes                     Yes
# 2329         No       No             Yes                      No
#
#      HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 623                 DSL                      Yes                  Yes
# 2069        Fiber optic                       No                   No
# 4955        Fiber optic                      Yes                  Yes
# 4789                DSL                      Yes                  Yes
# 2329                 No      No internet service  No internet service
#
#       HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 623                   Yes                   No                   No
# 2069                   No                   No                   No
# 4955                  Yes                  Yes                  Yes
# 4789                  Yes                  Yes                  Yes
# 2329  No internet service  No internet service  No internet service
#
#      HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 623                    No         Two year                Yes
# 2069                   No   Month-to-month                Yes
# 4955                  Yes   Month-to-month                Yes
# 4789                  Yes         Two year                 No
# 2329  No internet service   Month-to-month                 No
#
#                   PaymentMethod  Churn
# 623   Bank transfer (automatic)      0
# 2069           Electronic check      1
# 4955           Electronic check      1
# 4789    Credit card (automatic)      0
# 2329               Mailed check      0

# %%
data = data.replace(r'^\s*$', np.nan, regex=True)

# %%
data.isna().sum()
# Out:
# ClientPeriod                0
# MonthlySpending             0
# TotalSpent                  9
# Sex                         0
# IsSeniorCitizen             0
# HasPartner                  0
# HasChild                    0
# HasPhoneService             0
# HasMultiplePhoneNumbers     0
# HasInternetService          0
# HasOnlineSecurityService    0
# HasOnlineBackup             0
# HasDeviceProtection         0
# HasTechSupportAccess        0
# HasOnlineTV                 0
# HasMovieSubscription        0
# HasContractPhone            0
# IsBillingPaperless          0
# PaymentMethod               0
# Churn                       0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isna().sum()
# Out:
# ClientPeriod                0
# MonthlySpending             0
# TotalSpent                  0
# Sex                         0
# IsSeniorCitizen             0
# HasPartner                  0
# HasChild                    0
# HasPhoneService             0
# HasMultiplePhoneNumbers     0
# HasInternetService          0
# HasOnlineSecurityService    0
# HasOnlineBackup             0
# HasDeviceProtection         0
# HasTechSupportAccess        0
# HasOnlineTV                 0
# HasMovieSubscription        0
# HasContractPhone            0
# IsBillingPaperless          0
# PaymentMethod               0
# Churn                       0
# dtype: int64

# %% [markdown]
# ## Анализ данных (3 балла)
#
# 1) Для численных призанков постройте гистограмму (*plt.hist(...)*) или boxplot (*plt.boxplot(...)*). Для категориальных посчитайте количество каждого значения для каждого признака. Для каждой колонки надо сделать *data.value_counts()* и построить bar диаграммы *plt.bar(...)* или круговые диаграммы *plt.pie(...)* (хорошо, елси вы сможете это сделать на одном гарфике с помощью *plt.subplots(...)*).
#
# 2) Посмотрите на распределение целевой переменной и скажите, являются ли классы несбалансированными.
#
# 3) (Если будет желание) Поиграйте с разными библиотеками для визуализации - *sns*, *pandas_visual_analysis*, etc.
#
# Второй пункт очень важен, потому что существуют задачи классификации с несбалансированными классами. Например, это может значить, что в датасете намного больше примеров 0 класса. В таких случаях нужно 1) не использовать accuracy как метрику 2) использовать методы борьбы с imbalanced dataset (обычно если датасет сильно несбалансирован, т.е. класса 1 в 20 раз меньше класса 0).

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)

ax1.boxplot([data["ClientPeriod"].values], label=["ClientPeriod"])
ax2.boxplot([data["MonthlySpending"].values], label=["MonthlySpending"])
ax3.boxplot([data["TotalSpent"].values.astype('float')], label=["TotalSpent"])

fig.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(12,10))
fig.subplots_adjust(hspace=0.2)

axes = axes.flatten()
for i, ax in enumerate(axes):
  axes[i].pie(data[cat_cols[i]].value_counts(), autopct='%1.1f%%')
  axes[i].set_title(cat_cols[i])

# %%
plt.title("Target")
plt.bar(data["Churn"].unique(), data["Churn"].value_counts())
plt.show()

# Да,классы являются несбалансированными

# %% [markdown]
# (Дополнительно) Если вы нашли какие-то ошибки в данных или выбросы, то можете их убрать. Тут можно поэксперементировать с обработкой данных как угодно, но не за баллы.

# %%
# YOUR CODE

# %% [markdown]
# ## Применение линейных моделей (3 балла)
#
# 1) Обработайте данные для того, чтобы к ним можно было применить LogisticRegression. Т.е. отнормируйте числовые признаки, а категориальные закодируйте с помощью one-hot-encoding'а.
#
# 2) С помощью кроссвалидации или разделения на train/valid выборку протестируйте разные значения гиперпараметра C и выберите лучший (можно тестировать С=100, 10, 1, 0.1, 0.01, 0.001) по метрике ROC-AUC.
#
# Если вы разделяете на train/valid, то используйте LogisticRegressionCV. Он сам при вызове .fit() подберет параметр С. (не забудьте передать scroing='roc_auc', чтобы при кроссвалидации сравнивались значения этой метрики, и refit=True, чтобы при потом модель обучилась на всем датасете с лучшим параметром C).
#
#
# (более сложный вариант) Если вы будете использовать кроссвалидацию, то преобразования данных и LogisticRegression нужно соединить в один Pipeline с помощью make_pipeline, как это делалось во втором семинаре. Потом pipeline надо передать в GridSearchCV. Для one-hot-encoding'a можно испльзовать комбинацию LabelEncoder + OneHotEncoder (сначала превращаем строчки в числа, а потом числа првращаем в one-hot вектора.)

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score, roc_curve

# %%
num_indices = [data.columns.get_loc(c) for c in num_cols if c in data]
numeric_data = data[data.columns[num_indices]]

# %%
cat_indices = [data.columns.get_loc(c) for c in cat_cols if c in data]
cat_data = data[data.columns[cat_indices]]
dummy_features = pd.get_dummies(cat_data)
dummy_features
# Out:
#       IsSeniorCitizen  Sex_Female  Sex_Male  HasPartner_No  HasPartner_Yes  \
# 0                   0       False      True          False            True
# 1                   0       False      True          False            True
# 2                   0       False      True           True           False
# 3                   1        True     False          False            True
# 4                   0        True     False          False            True
# ...               ...         ...       ...            ...             ...
# 5277                0       False      True           True           False
# 5278                0       False      True          False            True
# 5279                0       False      True           True           False
# 5280                0        True     False           True           False
# 5281                0        True     False           True           False
#
#       HasChild_No  HasChild_Yes  HasPhoneService_No  HasPhoneService_Yes  \
# 0           False          True               False                 True
# 1            True         False               False                 True
# 2            True         False               False                 True
# 3            True         False               False                 True
# 4           False          True               False                 True
# ...           ...           ...                 ...                  ...
# 5277         True         False                True                False
# 5278         True         False                True                False
# 5279         True         False               False                 True
# 5280         True         False               False                 True
# 5281        False          True               False                 True
#
#       HasMultiplePhoneNumbers_No  ...  HasMovieSubscription_Yes  \
# 0                           True  ...                     False
# 1                          False  ...                     False
# 2                           True  ...                     False
# 3                          False  ...                     False
# 4                          False  ...                      True
# ...                          ...  ...                       ...
# 5277                       False  ...                     False
# 5278                       False  ...                     False
# 5279                        True  ...                     False
# 5280                       False  ...                     False
# 5281                       False  ...                     False
#
#       HasContractPhone_Month-to-month  HasContractPhone_One year  \
# 0                               False                       True
# 1                               False                      False
# 2                                True                      False
# 3                                True                      False
# 4                               False                      False
# ...                               ...                        ...
# 5277                             True                      False
# 5278                            False                       True
# 5279                             True                      False
# 5280                             True                      False
# 5281                             True                      False
#
#       HasContractPhone_Two year  IsBillingPaperless_No  \
# 0                         False                   True
# 1                          True                   True
# 2                         False                  False
# 3                         False                   True
# 4                          True                   True
# ...                         ...                    ...
# 5277                      False                   True
# 5278                      False                  False
# 5279                      False                   True
# 5280                      False                  False
# 5281                      False                  False
#
#       IsBillingPaperless_Yes  PaymentMethod_Bank transfer (automatic)  \
# 0                      False                                    False
# 1                      False                                    False
# 2                       True                                    False
# 3                      False                                    False
# 4                      False                                    False
# ...                      ...                                      ...
# 5277                   False                                    False
# 5278                    True                                     True
# 5279                   False                                    False
# 5280                    True                                    False
# 5281                    True                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                     False                           False
# 1                                      True                           False
# 2                                     False                            True
# 3                                     False                           False
# 4                                      True                           False
# ...                                     ...                             ...
# 5277                                  False                            True
# 5278                                  False                           False
# 5279                                  False                           False
# 5280                                   True                           False
# 5281                                  False                           False
#
#       PaymentMethod_Mailed check
# 0                           True
# 1                          False
# 2                          False
# 3                           True
# 4                          False
# ...                          ...
# 5277                       False
# 5278                       False
# 5279                        True
# 5280                       False
# 5281                        True
#
# [5273 rows x 42 columns]

# %%
X = pd.concat([numeric_data, dummy_features], axis=1)
y = data["Churn"]

X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, shuffle=True, test_size=0.2, random_state=44)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
C_values = [100., 10., 1., 0.1, 0.01, 0.001]
model = LogisticRegressionCV(Cs=C_values, scoring='roc_auc', refit=True, cv=5, random_state=44, max_iter=100)
model.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(Cs=[100.0, 10.0, 1.0, 0.1, 0.01, 0.001], cv=5,
#                      random_state=44, scoring='roc_auc')

# %%
y_train_predicted = model.predict_proba(X_train)[:, 1]
y_test_predicted = model.predict_proba(X_test)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
scores = model.scores_[1]
scores
# Out:
# array([[0.85482716, 0.85482716, 0.85532119, 0.85410402, 0.85141908,
#         0.84781052],
#        [0.84724847, 0.8471912 , 0.8471912 , 0.84492869, 0.83916502,
#         0.82949924],
#        [0.82320217, 0.82319501, 0.82294441, 0.82433342, 0.82559355,
#         0.82686084],
#        [0.85221863, 0.85221863, 0.85131967, 0.8488817 , 0.84629989,
#         0.84126573],
#        [0.84694714, 0.84694714, 0.84642215, 0.84496944, 0.842589  ,
#         0.83390147]])

# %% [markdown]
# Лучшее качество 0,84 получилось с С = 100
#
# ---

# %% [markdown]
# ## Применение градиентного бустинга (2 балла)
#
# Если вы хотите получить баллы за точный ответ, то стоит попробовать градиентный бустинг. Часто градиентный бустинг с параметрами по умолчанию даст вам 80% результата за 0% усилий.
#
# Мы будем использовать catboost, поэтому нам не надо кодировать категориальные признаки. Catboost сделает это сам (в .fit() надо передать cat_features=cat_cols). А численные признаки нормировать для моделей, основанных на деревьях не нужно.
#
# 1) Разделите выборку на train/valid. Протестируйте catboost cо стандартными параметрами.
#
# 2) Протестируйте разные занчения параметров количества деревьев и learning_rate'а и выберите лучшую по метрике ROC-AUC комбинацию.
#
# (Дополнительно) Есть некоторые сложности с тем, чтобы использовать CatBoostClassifier вместе с GridSearchCV, поэтому мы не просим использовать кроссвалидацию. Но можете попробовать)

# %%
# !pip install catboost -q

# %%
import catboost
from sklearn.metrics import roc_auc_score, roc_curve

# %%
X = data.drop(["Churn"], axis=1)
y = data["Churn"]

X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, shuffle=True, test_size=0.2, random_state=44)

# %%
boosting_model = catboost.CatBoostClassifier(n_estimators=100,
                                             cat_features=cat_indices)

boosting_model.fit(X_train, y_train)

y_train_predicted = boosting_model.predict_proba(X_train)[:, 1]
y_test_predicted = boosting_model.predict_proba(X_test)[:, 1]
# Out:
# Learning rate set to 0.157346
# 0:	learn: 0.6379010	total: 5.86ms	remaining: 580ms
# 1:	learn: 0.5970806	total: 10.5ms	remaining: 515ms
# 2:	learn: 0.5653526	total: 14.8ms	remaining: 480ms
# 3:	learn: 0.5404200	total: 20ms	remaining: 479ms
# 4:	learn: 0.5214585	total: 24.5ms	remaining: 466ms
# 5:	learn: 0.5054834	total: 29.6ms	remaining: 463ms
# 6:	learn: 0.4936738	total: 34ms	remaining: 452ms
# 7:	learn: 0.4812560	total: 38.6ms	remaining: 444ms
# 8:	learn: 0.4703268	total: 43.1ms	remaining: 436ms
# 9:	learn: 0.4627531	total: 47.8ms	remaining: 430ms
# 10:	learn: 0.4542958	total: 52.5ms	remaining: 425ms
# 11:	learn: 0.4478027	total: 57.3ms	remaining: 420ms
# 12:	learn: 0.4422378	total: 61.7ms	remaining: 413ms
# 13:	learn: 0.4368549	total: 66.5ms	remaining: 408ms
# 14:	learn: 0.4331649	total: 69.9ms	remaining: 396ms
# 15:	learn: 0.4291264	total: 74.3ms	remaining: 390ms
# 16:	learn: 0.4258962	total: 78.8ms	remaining: 385ms
# 17:	learn: 0.4233949	total: 83.1ms	remaining: 379ms
# 18:	learn: 0.4209502	total: 87.6ms	remaining: 373ms
# 19:	learn: 0.4177901	total: 92.1ms	remaining: 368ms
# 20:	learn: 0.4157680	total: 96.4ms	remaining: 363ms
# 21:	learn: 0.4148743	total: 98.7ms	remaining: 350ms
# 22:	learn: 0.4136989	total: 104ms	remaining: 348ms
# 23:	learn: 0.4118247	total: 110ms	remaining: 349ms
# 24:	learn: 0.4112441	total: 113ms	remaining: 338ms
# 25:	learn: 0.4100983	total: 117ms	remaining: 333ms
# 26:	learn: 0.4084748	total: 122ms	remaining: 329ms
# 27:	learn: 0.4079836	total: 124ms	remaining: 319ms
# 28:	learn: 0.4067419	total: 128ms	remaining: 314ms
# 29:	learn: 0.4065013	total: 130ms	remaining: 303ms
# 30:	learn: 0.4046315	total: 134ms	remaining: 299ms
# 31:	learn: 0.4036640	total: 139ms	remaining: 295ms
# 32:	learn: 0.4031464	total: 143ms	remaining: 291ms
# 33:	learn: 0.4021227	total: 148ms	remaining: 287ms
# 34:	learn: 0.4011523	total: 152ms	remaining: 283ms
# 35:	learn: 0.4002646	total: 157ms	remaining: 278ms
# 36:	learn: 0.4000324	total: 161ms	remaining: 274ms
# 37:	learn: 0.3988310	total: 165ms	remaining: 270ms
# 38:	learn: 0.3984992	total: 170ms	remaining: 266ms
# 39:	learn: 0.3980681	total: 174ms	remaining: 261ms
# 40:	learn: 0.3976815	total: 179ms	remaining: 257ms
# 41:	learn: 0.3970747	total: 183ms	remaining: 253ms
# 42:	learn: 0.3965820	total: 188ms	remaining: 249ms
# 43:	learn: 0.3963439	total: 192ms	remaining: 244ms
# 44:	learn: 0.3957179	total: 199ms	remaining: 243ms
# 45:	learn: 0.3956956	total: 204ms	remaining: 239ms
# 46:	learn: 0.3950128	total: 208ms	remaining: 235ms
# 47:	learn: 0.3948426	total: 213ms	remaining: 230ms
# 48:	learn: 0.3945592	total: 217ms	remaining: 226ms
# 49:	learn: 0.3944007	total: 221ms	remaining: 221ms
# 50:	learn: 0.3943557	total: 225ms	remaining: 216ms
# 51:	learn: 0.3928586	total: 229ms	remaining: 211ms
# 52:	learn: 0.3925964	total: 233ms	remaining: 207ms
# 53:	learn: 0.3925250	total: 238ms	remaining: 203ms
# 54:	learn: 0.3919164	total: 242ms	remaining: 198ms
# 55:	learn: 0.3919162	total: 244ms	remaining: 192ms
# 56:	learn: 0.3912762	total: 249ms	remaining: 187ms
# 57:	learn: 0.3910556	total: 253ms	remaining: 183ms
# 58:	learn: 0.3896551	total: 257ms	remaining: 179ms
# 59:	learn: 0.3895306	total: 262ms	remaining: 174ms
# 60:	learn: 0.3891003	total: 266ms	remaining: 170ms
# 61:	learn: 0.3887115	total: 272ms	remaining: 167ms
# 62:	learn: 0.3886437	total: 276ms	remaining: 162ms
# 63:	learn: 0.3882061	total: 281ms	remaining: 158ms
# 64:	learn: 0.3876689	total: 285ms	remaining: 154ms
# 65:	learn: 0.3876633	total: 289ms	remaining: 149ms
# 66:	learn: 0.3874746	total: 294ms	remaining: 145ms
# 67:	learn: 0.3874707	total: 299ms	remaining: 140ms
# 68:	learn: 0.3874036	total: 303ms	remaining: 136ms
# 69:	learn: 0.3871575	total: 309ms	remaining: 132ms
# 70:	learn: 0.3869920	total: 313ms	remaining: 128ms
# 71:	learn: 0.3867753	total: 317ms	remaining: 123ms
# 72:	learn: 0.3867690	total: 322ms	remaining: 119ms
# 73:	learn: 0.3867649	total: 326ms	remaining: 115ms
# 74:	learn: 0.3866640	total: 331ms	remaining: 110ms
# 75:	learn: 0.3864855	total: 335ms	remaining: 106ms
# 76:	learn: 0.3864778	total: 339ms	remaining: 101ms
# 77:	learn: 0.3861103	total: 344ms	remaining: 97ms
# 78:	learn: 0.3860112	total: 348ms	remaining: 92.6ms
# 79:	learn: 0.3857505	total: 353ms	remaining: 88.2ms
# 80:	learn: 0.3857284	total: 357ms	remaining: 83.8ms
# 81:	learn: 0.3857226	total: 362ms	remaining: 79.4ms
# 82:	learn: 0.3857171	total: 366ms	remaining: 75ms
# 83:	learn: 0.3857131	total: 371ms	remaining: 70.6ms
# 84:	learn: 0.3849930	total: 375ms	remaining: 66.2ms
# 85:	learn: 0.3842908	total: 381ms	remaining: 62ms
# 86:	learn: 0.3842878	total: 385ms	remaining: 57.6ms
# 87:	learn: 0.3835221	total: 390ms	remaining: 53.1ms
# 88:	learn: 0.3834431	total: 410ms	remaining: 50.6ms
# 89:	learn: 0.3834383	total: 428ms	remaining: 47.6ms
# 90:	learn: 0.3834353	total: 438ms	remaining: 43.3ms
# 91:	learn: 0.3834306	total: 443ms	remaining: 38.6ms
# 92:	learn: 0.3833158	total: 456ms	remaining: 34.3ms
# 93:	learn: 0.3828679	total: 462ms	remaining: 29.5ms
# 94:	learn: 0.3828634	total: 468ms	remaining: 24.6ms
# 95:	learn: 0.3826773	total: 472ms	remaining: 19.7ms
# 96:	learn: 0.3820089	total: 478ms	remaining: 14.8ms
# 97:	learn: 0.3813568	total: 483ms	remaining: 9.86ms
# 98:	learn: 0.3810321	total: 489ms	remaining: 4.94ms
# 99:	learn: 0.3806679	total: 494ms	remaining: 0us

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(10,7))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# Выпишите, какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# Лучшее качество 0,8446 получилось с С = 100

# %% [markdown]
# # Предсказания

# %%
best_model = boosting_model

# %%
X_test = pd.read_csv('./test.csv')
submission = pd.read_csv('./submission.csv')

submission['Churn'] = boosting_model.predict_proba(X_test)

submission.to_csv('./my_submission.csv', index=False)

# %% [markdown]
# Лучшее решение отправьте в Stepik.
