# %% [markdown]
# <p style="align: center;"><img align=center src="https://drive.google.com/uc?export=view&id=1I8kDikouqpH4hf7JBiSYAeNT2IO52T-T" width=600 height=480/></p>
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Домашнее задание. Generative adversarial networks</b></h3>

# %% [markdown]
# В этом домашнем задании вы обучите GAN генерировать лица людей и посмотрите на то, как можно оценивать качество генерации

# %%
import os
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as tt
import torch
import torch.nn as nn
import cv2
from tqdm.notebook import tqdm
from torchvision.utils import save_image
from torchvision.utils import make_grid
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style='darkgrid', font_scale=1.2)

# %% [markdown]
# ## Часть 1. Подготовка данных (0.5 балла)

# %% [markdown]
# В качестве обучающей выборки возьмем часть датасета [Flickr Faces](https://github.com/NVlabs/ffhq-dataset), который содержит изображения лиц людей в высоком разрешении (1024х1024). Оригинальный датасет очень большой, поэтому мы возьмем его часть. Скачать датасет можно [здесь](https://www.kaggle.com/datasets/tommykamaz/faces-dataset-small?resource=download-directory) и  [здесь](https://drive.google.com/file/d/1inyvLrN5wKBGCxQ4znMKBc64uL4uP_2x/view?usp=drive_link)

# %% [markdown]
# Давайте загрузим наши изображения. Напишите функцию, которая строит DataLoader для изображений, при этом меняя их размер до нужного значения (размер 1024 слишком большой, поэтому мы рекомендуем взять размер 128 либо немного больше)

# %%
# !unzip /content/sample_data/faces_128.zip -d faces_128
# Out:
# Archive:  /content/sample_data/faces_128.zip
#    creating: faces_128/faces_128/
#   inflating: faces_128/faces_128/00055.png
#   inflating: faces_128/faces_128/00237.png
#   inflating: faces_128/faces_128/00240.png
#   inflating: faces_128/faces_128/00241.png
#   inflating: faces_128/faces_128/00242.png
#   inflating: faces_128/faces_128/00243.png
#   inflating: faces_128/faces_128/00244.png
#   inflating: faces_128/faces_128/00245.png
#   inflating: faces_128/faces_128/00246.png
#   inflating: faces_128/faces_128/00247.png
#   inflating: faces_128/faces_128/00248.png
#   inflating: faces_128/faces_128/00249.png
#   inflating: faces_128/faces_128/00253.png
#   inflating: faces_128/faces_128/00255.png
#   inflating: faces_128/faces_128/00257.png
#   inflating: faces_128/faces_128/00258.png
#   inflating: faces_128/faces_128/00259.png
#   inflating: faces_128/faces_128/00260.png
#   inflating: faces_128/faces_128/00261.png
#   inflating: faces_128/faces_128/00262.png
#   inflating: faces_128/faces_128/00263.png
#   inflating: faces_128/faces_128/00264.png
#   inflating: faces_128/faces_128/00265.png
#   inflating: faces_128/faces_128/00266.png
#   inflating: faces_128/faces_128/00267.png
#   inflating: faces_128/faces_128/00268.png
#   inflating: faces_128/faces_128/00269.png
#   inflating: faces_128/faces_128/00270.png
#   inflating: faces_128/faces_128/00271.png
#   inflating: faces_128/faces_128/00272.png
#   inflating: faces_128/faces_128/00273.png
#   inflating: faces_128/faces_128/00274.png
#   inflating: faces_128/faces_128/00275.png
#   inflating: faces_128/faces_128/00276.png
#   inflating: faces_128/faces_128/00277.png
#   inflating: faces_128/faces_128/00278.png
#   inflating: faces_128/faces_128/00279.png
#   inflating: faces_128/faces_128/00280.png
#   inflating: faces_128/faces_128/00281.png
#   inflating: faces_128/faces_128/00282.png
#   inflating: faces_128/faces_128/00283.png
#   inflating: faces_128/faces_128/00284.png
#   inflating: faces_128/faces_128/00285.png
#   inflating: faces_128/faces_128/00286.png
#   inflating: faces_128/faces_128/00287.png
#   inflating: faces_128/faces_128/00288.png
#   inflating: faces_128/faces_128/00289.png
#   inflating: faces_128/faces_128/00290.png
#   inflating: faces_128/faces_128/00291.png
#   inflating: faces_128/faces_128/00292.png
#   inflating: faces_128/faces_128/00293.png
#   inflating: faces_128/faces_128/00294.png
#   inflating: faces_128/faces_128/00295.png
#   inflating: faces_128/faces_128/00296.png
#   inflating: faces_128/faces_128/00297.png
#   inflating: faces_128/faces_128/00298.png
#   inflating: faces_128/faces_128/00299.png
#   inflating: faces_128/faces_128/00333.png
#   inflating: faces_128/faces_128/00350.png
#   inflating: faces_128/faces_128/00351.png
#   inflating: faces_128/faces_128/00352.png
#   inflating: faces_128/faces_128/00353.png
#   inflating: faces_128/faces_128/00354.png
#   inflating: faces_128/faces_128/00355.png
#   inflating: faces_128/faces_128/00356.png
#   inflating: faces_128/faces_128/00357.png
#   inflating: faces_128/faces_128/00358.png
#   inflating: faces_128/faces_128/00359.png
#   inflating: faces_128/faces_128/00360.png
#   inflating: faces_128/faces_128/00361.png
#   inflating: faces_128/faces_128/00362.png
#   inflating: faces_128/faces_128/00363.png
#   inflating: faces_128/faces_128/00364.png
#   inflating: faces_128/faces_128/00365.png
#   inflating: faces_128/faces_128/00366.png
#   inflating: faces_128/faces_128/00367.png
#   inflating: faces_128/faces_128/00368.png
#   inflating: faces_128/faces_128/00369.png
#   inflating: faces_128/faces_128/00370.png
#   inflating: faces_128/faces_128/00371.png
#   inflating: faces_128/faces_128/00372.png
#   inflating: faces_128/faces_128/00373.png
#   inflating: faces_128/faces_128/00374.png
#   inflating: faces_128/faces_128/00379.png
#   inflating: faces_128/faces_128/00400.png
#   inflating: faces_128/faces_128/00401.png
#   inflating: faces_128/faces_128/00402.png
#   inflating: faces_128/faces_128/00403.png
#   inflating: faces_128/faces_128/00404.png
#   inflating: faces_128/faces_128/00405.png
#   inflating: faces_128/faces_128/00406.png
#   inflating: faces_128/faces_128/00407.png
#   inflating: faces_128/faces_128/00408.png
#   inflating: faces_128/faces_128/00409.png
#   inflating: faces_128/faces_128/00410.png
#   inflating: faces_128/faces_128/00411.png
#   inflating: faces_128/faces_128/00412.png
#   inflating: faces_128/faces_128/00413.png
#   inflating: faces_128/faces_128/00414.png
#   inflating: faces_128/faces_128/00415.png
#   inflating: faces_128/faces_128/00416.png
#   inflating: faces_128/faces_128/00417.png
#   inflating: faces_128/faces_128/00418.png
#   inflating: faces_128/faces_128/00419.png
#   inflating: faces_128/faces_128/00420.png
#   inflating: faces_128/faces_128/00421.png
#   inflating: faces_128/faces_128/00422.png
#   inflating: faces_128/faces_128/00423.png
#   inflating: faces_128/faces_128/00424.png
#   inflating: faces_128/faces_128/00450.png
#   inflating: faces_128/faces_128/00451.png
#   inflating: faces_128/faces_128/00452.png
#   inflating: faces_128/faces_128/00453.png
#   inflating: faces_128/faces_128/00454.png
#   inflating: faces_128/faces_128/00455.png
#   inflating: faces_128/faces_128/00456.png
#   inflating: faces_128/faces_128/00457.png
#   inflating: faces_128/faces_128/00458.png
#   inflating: faces_128/faces_128/00459.png
#   inflating: faces_128/faces_128/00460.png
#   inflating: faces_128/faces_128/00461.png
#   inflating: faces_128/faces_128/00462.png
#   inflating: faces_128/faces_128/00463.png
#   inflating: faces_128/faces_128/00464.png
#   inflating: faces_128/faces_128/00465.png
#   inflating: faces_128/faces_128/00466.png
#   inflating: faces_128/faces_128/00467.png
#   inflating: faces_128/faces_128/00468.png
#   inflating: faces_128/faces_128/00469.png
#   inflating: faces_128/faces_128/00470.png
#   inflating: faces_128/faces_128/00471.png
#   inflating: faces_128/faces_128/00472.png
#   inflating: faces_128/faces_128/00473.png
#   inflating: faces_128/faces_128/00474.png
#   inflating: faces_128/faces_128/00475.png
#   inflating: faces_128/faces_128/00476.png
#   inflating: faces_128/faces_128/00477.png
#   inflating: faces_128/faces_128/00478.png
#   inflating: faces_128/faces_128/00479.png
#   inflating: faces_128/faces_128/00480.png
#   inflating: faces_128/faces_128/00481.png
#   inflating: faces_128/faces_128/00482.png
#   inflating: faces_128/faces_128/00483.png
#   inflating: faces_128/faces_128/00484.png
#   inflating: faces_128/faces_128/00485.png
#   inflating: faces_128/faces_128/00486.png
#   inflating: faces_128/faces_128/00487.png
#   inflating: faces_128/faces_128/00488.png
#   inflating: faces_128/faces_128/00489.png
#   inflating: faces_128/faces_128/00490.png
#   inflating: faces_128/faces_128/00491.png
#   inflating: faces_128/faces_128/00492.png
#   inflating: faces_128/faces_128/00493.png
#   inflating: faces_128/faces_128/00494.png
#   inflating: faces_128/faces_128/00495.png
#   inflating: faces_128/faces_128/00496.png
#   inflating: faces_128/faces_128/00497.png
#   inflating: faces_128/faces_128/00498.png
#   inflating: faces_128/faces_128/00499.png
#   inflating: faces_128/faces_128/00525.png
#   inflating: faces_128/faces_128/00526.png
#   inflating: faces_128/faces_128/00527.png
#   inflating: faces_128/faces_128/00528.png
#   inflating: faces_128/faces_128/00529.png
#   inflating: faces_128/faces_128/00530.png
#   inflating: faces_128/faces_128/00531.png
#   inflating: faces_128/faces_128/00532.png
#   inflating: faces_128/faces_128/00533.png
#   inflating: faces_128/faces_128/00534.png
#   inflating: faces_128/faces_128/00535.png
#   inflating: faces_128/faces_128/00536.png
#   inflating: faces_128/faces_128/00537.png
#   inflating: faces_128/faces_128/00538.png
#   inflating: faces_128/faces_128/00539.png
#   inflating: faces_128/faces_128/00540.png
#   inflating: faces_128/faces_128/00541.png
#   inflating: faces_128/faces_128/00542.png
#   inflating: faces_128/faces_128/00543.png
#   inflating: faces_128/faces_128/00544.png
#   inflating: faces_128/faces_128/00545.png
#   inflating: faces_128/faces_128/00546.png
#   inflating: faces_128/faces_128/00547.png
#   inflating: faces_128/faces_128/00548.png
#   inflating: faces_128/faces_128/00549.png
#   inflating: faces_128/faces_128/00550.png
#   inflating: faces_128/faces_128/00551.png
#   inflating: faces_128/faces_128/00552.png
#   inflating: faces_128/faces_128/00553.png
#   inflating: faces_128/faces_128/00554.png
#   inflating: faces_128/faces_128/00555.png
#   inflating: faces_128/faces_128/00556.png
#   inflating: faces_128/faces_128/00557.png
#   inflating: faces_128/faces_128/00558.png
#   inflating: faces_128/faces_128/00559.png
#   inflating: faces_128/faces_128/00560.png
#   inflating: faces_128/faces_128/00561.png
#   inflating: faces_128/faces_128/00562.png
#   inflating: faces_128/faces_128/00563.png
#   inflating: faces_128/faces_128/00564.png
#   inflating: faces_128/faces_128/00565.png
#   inflating: faces_128/faces_128/00566.png
#   inflating: faces_128/faces_128/00567.png
#   inflating: faces_128/faces_128/00568.png
#   inflating: faces_128/faces_128/00569.png
#   inflating: faces_128/faces_128/00570.png
#   inflating: faces_128/faces_128/00571.png
#   inflating: faces_128/faces_128/00572.png
#   inflating: faces_128/faces_128/00573.png
#   inflating: faces_128/faces_128/00574.png
#   inflating: faces_128/faces_128/00600.png
#   inflating: faces_128/faces_128/00601.png
#   inflating: faces_128/faces_128/00602.png
#   inflating: faces_128/faces_128/00603.png
#   inflating: faces_128/faces_128/00604.png
#   inflating: faces_128/faces_128/00605.png
#   inflating: faces_128/faces_128/00606.png
#   inflating: faces_128/faces_128/00607.png
#   inflating: faces_128/faces_128/00608.png
#   inflating: faces_128/faces_128/00609.png
#   inflating: faces_128/faces_128/00610.png
#   inflating: faces_128/faces_128/00611.png
#   inflating: faces_128/faces_128/00612.png
#   inflating: faces_128/faces_128/00613.png
#   inflating: faces_128/faces_128/00614.png
#   inflating: faces_128/faces_128/00615.png
#   inflating: faces_128/faces_128/00616.png
#   inflating: faces_128/faces_128/00617.png
#   inflating: faces_128/faces_128/00618.png
#   inflating: faces_128/faces_128/00619.png
#   inflating: faces_128/faces_128/00620.png
#   inflating: faces_128/faces_128/00621.png
#   inflating: faces_128/faces_128/00622.png
#   inflating: faces_128/faces_128/00623.png
#   inflating: faces_128/faces_128/00624.png
#   inflating: faces_128/faces_128/00664.png
#   inflating: faces_128/faces_128/00665.png
#   inflating: faces_128/faces_128/00666.png
#   inflating: faces_128/faces_128/00667.png
#   inflating: faces_128/faces_128/00668.png
#   inflating: faces_128/faces_128/00669.png
#   inflating: faces_128/faces_128/00670.png
#   inflating: faces_128/faces_128/00671.png
#   inflating: faces_128/faces_128/00672.png
#   inflating: faces_128/faces_128/00673.png
#   inflating: faces_128/faces_128/00674.png
#   inflating: faces_128/faces_128/00675.png
#   inflating: faces_128/faces_128/00676.png
#   inflating: faces_128/faces_128/00677.png
#   inflating: faces_128/faces_128/00678.png
#   inflating: faces_128/faces_128/00679.png
#   inflating: faces_128/faces_128/00680.png
#   inflating: faces_128/faces_128/00681.png
#   inflating: faces_128/faces_128/00682.png
#   inflating: faces_128/faces_128/00683.png
#   inflating: faces_128/faces_128/00684.png
#   inflating: faces_128/faces_128/00685.png
#   inflating: faces_128/faces_128/00686.png
#   inflating: faces_128/faces_128/00687.png
#   inflating: faces_128/faces_128/00688.png
#   inflating: faces_128/faces_128/00689.png
#   inflating: faces_128/faces_128/00690.png
#   inflating: faces_128/faces_128/00691.png
#   inflating: faces_128/faces_128/00692.png
#   inflating: faces_128/faces_128/00693.png
#   inflating: faces_128/faces_128/00694.png
#   inflating: faces_128/faces_128/00695.png
#   inflating: faces_128/faces_128/00696.png
#   inflating: faces_128/faces_128/00697.png
#   inflating: faces_128/faces_128/00698.png
#   inflating: faces_128/faces_128/00699.png
#   inflating: faces_128/faces_128/00700.png
#   inflating: faces_128/faces_128/00701.png
#   inflating: faces_128/faces_128/00702.png
#   inflating: faces_128/faces_128/00703.png
#   inflating: faces_128/faces_128/00704.png
#   inflating: faces_128/faces_128/00705.png
#   inflating: faces_128/faces_128/00706.png
#   inflating: faces_128/faces_128/00707.png
#   inflating: faces_128/faces_128/00708.png
#   inflating: faces_128/faces_128/00709.png
#   inflating: faces_128/faces_128/00710.png
#   inflating: faces_128/faces_128/00711.png
#   inflating: faces_128/faces_128/00712.png
#   inflating: faces_128/faces_128/00713.png
#   inflating: faces_128/faces_128/00714.png
#   inflating: faces_128/faces_128/00715.png
#   inflating: faces_128/faces_128/00716.png
#   inflating: faces_128/faces_128/00717.png
#   inflating: faces_128/faces_128/00718.png
#   inflating: faces_128/faces_128/00719.png
#   inflating: faces_128/faces_128/00720.png
#   inflating: faces_128/faces_128/00721.png
#   inflating: faces_128/faces_128/00722.png
#   inflating: faces_128/faces_128/00723.png
#   inflating: faces_128/faces_128/00724.png
#   inflating: faces_128/faces_128/00737.png
#   inflating: faces_128/faces_128/00738.png
#   inflating: faces_128/faces_128/00739.png
#   inflating: faces_128/faces_128/00740.png
#   inflating: faces_128/faces_128/00741.png
#   inflating: faces_128/faces_128/00742.png
#   inflating: faces_128/faces_128/00743.png
#   inflating: faces_128/faces_128/00744.png
#   inflating: faces_128/faces_128/00745.png
#   inflating: faces_128/faces_128/00746.png
#   inflating: faces_128/faces_128/00747.png
#   inflating: faces_128/faces_128/00748.png
#   inflating: faces_128/faces_128/00749.png
#   inflating: faces_128/faces_128/00750.png
#   inflating: faces_128/faces_128/00751.png
#   inflating: faces_128/faces_128/00752.png
#   inflating: faces_128/faces_128/00753.png
#   inflating: faces_128/faces_128/00754.png
#   inflating: faces_128/faces_128/00755.png
#   inflating: faces_128/faces_128/00756.png
#   inflating: faces_128/faces_128/00757.png
#   inflating: faces_128/faces_128/00758.png
#   inflating: faces_128/faces_128/00759.png
#   inflating: faces_128/faces_128/00760.png
#   inflating: faces_128/faces_128/00761.png
#   inflating: faces_128/faces_128/00762.png
#   inflating: faces_128/faces_128/00763.png
#   inflating: faces_128/faces_128/00764.png
#   inflating: faces_128/faces_128/00765.png
#   inflating: faces_128/faces_128/00766.png
#   inflating: faces_128/faces_128/00767.png
#   inflating: faces_128/faces_128/00768.png
#   inflating: faces_128/faces_128/00769.png
#   inflating: faces_128/faces_128/00770.png
#   inflating: faces_128/faces_128/00771.png
#   inflating: faces_128/faces_128/00772.png
#   inflating: faces_128/faces_128/00773.png
#   inflating: faces_128/faces_128/00774.png
#   inflating: faces_128/faces_128/00775.png
#   inflating: faces_128/faces_128/00776.png
#   inflating: faces_128/faces_128/00777.png
#   inflating: faces_128/faces_128/00778.png
#   inflating: faces_128/faces_128/00779.png
#   inflating: faces_128/faces_128/00780.png
#   inflating: faces_128/faces_128/00781.png
#   inflating: faces_128/faces_128/00782.png
#   inflating: faces_128/faces_128/00783.png
#   inflating: faces_128/faces_128/00784.png
#   inflating: faces_128/faces_128/00785.png
#   inflating: faces_128/faces_128/00786.png
#   inflating: faces_128/faces_128/00787.png
#   inflating: faces_128/faces_128/00788.png
#   inflating: faces_128/faces_128/00789.png
#   inflating: faces_128/faces_128/00790.png
#   inflating: faces_128/faces_128/00791.png
#   inflating: faces_128/faces_128/00792.png
#   inflating: faces_128/faces_128/00793.png
#   inflating: faces_128/faces_128/00794.png
#   inflating: faces_128/faces_128/00795.png
#   inflating: faces_128/faces_128/00796.png
#   inflating: faces_128/faces_128/00797.png
#   inflating: faces_128/faces_128/00798.png
#   inflating: faces_128/faces_128/00799.png
#   inflating: faces_128/faces_128/00800.png
#   inflating: faces_128/faces_128/00801.png
#   inflating: faces_128/faces_128/00802.png
#   inflating: faces_128/faces_128/00803.png
#   inflating: faces_128/faces_128/00804.png
#   inflating: faces_128/faces_128/00805.png
#   inflating: faces_128/faces_128/00806.png
#   inflating: faces_128/faces_128/00807.png
#   inflating: faces_128/faces_128/00808.png
#   inflating: faces_128/faces_128/00809.png
#   inflating: faces_128/faces_128/00810.png
#   inflating: faces_128/faces_128/00811.png
#   inflating: faces_128/faces_128/00812.png
#   inflating: faces_128/faces_128/00813.png
#   inflating: faces_128/faces_128/00814.png
#   inflating: faces_128/faces_128/00815.png
#   inflating: faces_128/faces_128/00816.png
#   inflating: faces_128/faces_128/00817.png
#   inflating: faces_128/faces_128/00818.png
#   inflating: faces_128/faces_128/00819.png
#   inflating: faces_128/faces_128/00820.png
#   inflating: faces_128/faces_128/00821.png
#   inflating: faces_128/faces_128/00822.png
#   inflating: faces_128/faces_128/00823.png
#   inflating: faces_128/faces_128/00824.png
#   inflating: faces_128/faces_128/00825.png
#   inflating: faces_128/faces_128/00826.png
#   inflating: faces_128/faces_128/00827.png
#   inflating: faces_128/faces_128/00828.png
#   inflating: faces_128/faces_128/00829.png
#   inflating: faces_128/faces_128/00830.png
#   inflating: faces_128/faces_128/00831.png
#   inflating: faces_128/faces_128/00832.png
#   inflating: faces_128/faces_128/00833.png
#   inflating: faces_128/faces_128/00834.png
#   inflating: faces_128/faces_128/00835.png
#   inflating: faces_128/faces_128/00836.png
#   inflating: faces_128/faces_128/00837.png
#   inflating: faces_128/faces_128/00838.png
#   inflating: faces_128/faces_128/00839.png
#   inflating: faces_128/faces_128/00840.png
#   inflating: faces_128/faces_128/00841.png
#   inflating: faces_128/faces_128/00842.png
#   inflating: faces_128/faces_128/00843.png
#   inflating: faces_128/faces_128/00844.png
#   inflating: faces_128/faces_128/00845.png
#   inflating: faces_128/faces_128/00846.png
#   inflating: faces_128/faces_128/00847.png
#   inflating: faces_128/faces_128/00848.png
#   inflating: faces_128/faces_128/00849.png
#   inflating: faces_128/faces_128/00850.png
#   inflating: faces_128/faces_128/00851.png
#   inflating: faces_128/faces_128/00852.png
#   inflating: faces_128/faces_128/00853.png
#   inflating: faces_128/faces_128/00854.png
#   inflating: faces_128/faces_128/00855.png
#   inflating: faces_128/faces_128/00856.png
#   inflating: faces_128/faces_128/00857.png
#   inflating: faces_128/faces_128/00858.png
#   inflating: faces_128/faces_128/00859.png
#   inflating: faces_128/faces_128/00860.png
#   inflating: faces_128/faces_128/00861.png
#   inflating: faces_128/faces_128/00862.png
#   inflating: faces_128/faces_128/00863.png
#   inflating: faces_128/faces_128/00864.png
#   inflating: faces_128/faces_128/00865.png
#   inflating: faces_128/faces_128/00866.png
#   inflating: faces_128/faces_128/00867.png
#   inflating: faces_128/faces_128/00868.png
#   inflating: faces_128/faces_128/00869.png
#   inflating: faces_128/faces_128/00870.png
#   inflating: faces_128/faces_128/00871.png
#   inflating: faces_128/faces_128/00872.png
#   inflating: faces_128/faces_128/00873.png
#   inflating: faces_128/faces_128/00874.png
#   inflating: faces_128/faces_128/00875.png
#   inflating: faces_128/faces_128/00876.png
#   inflating: faces_128/faces_128/00877.png
#   inflating: faces_128/faces_128/00878.png
#   inflating: faces_128/faces_128/00879.png
#   inflating: faces_128/faces_128/00880.png
#   inflating: faces_128/faces_128/00881.png
#   inflating: faces_128/faces_128/00882.png
#   inflating: faces_128/faces_128/00883.png
#   inflating: faces_128/faces_128/00884.png
#   inflating: faces_128/faces_128/00885.png
#   inflating: faces_128/faces_128/00886.png
#   inflating: faces_128/faces_128/00887.png
#   inflating: faces_128/faces_128/00888.png
#   inflating: faces_128/faces_128/00889.png
#   inflating: faces_128/faces_128/00890.png
#   inflating: faces_128/faces_128/00891.png
#   inflating: faces_128/faces_128/00892.png
#   inflating: faces_128/faces_128/00893.png
#   inflating: faces_128/faces_128/00894.png
#   inflating: faces_128/faces_128/00895.png
#   inflating: faces_128/faces_128/00896.png
#   inflating: faces_128/faces_128/00897.png
#   inflating: faces_128/faces_128/00898.png
#   inflating: faces_128/faces_128/00899.png
#   inflating: faces_128/faces_128/00900.png
#   inflating: faces_128/faces_128/00901.png
#   inflating: faces_128/faces_128/00902.png
#   inflating: faces_128/faces_128/00903.png
#   inflating: faces_128/faces_128/00904.png
#   inflating: faces_128/faces_128/00905.png
#   inflating: faces_128/faces_128/00906.png
#   inflating: faces_128/faces_128/00907.png
#   inflating: faces_128/faces_128/00908.png
#   inflating: faces_128/faces_128/00909.png
#   inflating: faces_128/faces_128/00910.png
#   inflating: faces_128/faces_128/00911.png
#   inflating: faces_128/faces_128/00912.png
#   inflating: faces_128/faces_128/00913.png
#   inflating: faces_128/faces_128/00914.png
#   inflating: faces_128/faces_128/00915.png
#   inflating: faces_128/faces_128/00916.png
#   inflating: faces_128/faces_128/00917.png
#   inflating: faces_128/faces_128/00918.png
#   inflating: faces_128/faces_128/00919.png
#   inflating: faces_128/faces_128/00920.png
#   inflating: faces_128/faces_128/00921.png
#   inflating: faces_128/faces_128/00922.png
#   inflating: faces_128/faces_128/00923.png
#   inflating: faces_128/faces_128/00924.png
#   inflating: faces_128/faces_128/00925.png
#   inflating: faces_128/faces_128/00926.png
#   inflating: faces_128/faces_128/00927.png
#   inflating: faces_128/faces_128/00928.png
#   inflating: faces_128/faces_128/00929.png
#   inflating: faces_128/faces_128/00930.png
#   inflating: faces_128/faces_128/00931.png
#   inflating: faces_128/faces_128/00932.png
#   inflating: faces_128/faces_128/00933.png
#   inflating: faces_128/faces_128/00934.png
#   inflating: faces_128/faces_128/00935.png
#   inflating: faces_128/faces_128/00936.png
#   inflating: faces_128/faces_128/00937.png
#   inflating: faces_128/faces_128/00938.png
#   inflating: faces_128/faces_128/00939.png
#   inflating: faces_128/faces_128/00940.png
#   inflating: faces_128/faces_128/00941.png
#   inflating: faces_128/faces_128/00942.png
#   inflating: faces_128/faces_128/00943.png
#   inflating: faces_128/faces_128/00944.png
#   inflating: faces_128/faces_128/00945.png
#   inflating: faces_128/faces_128/00946.png
#   inflating: faces_128/faces_128/00947.png
#   inflating: faces_128/faces_128/00948.png
#   inflating: faces_128/faces_128/00949.png
#   inflating: faces_128/faces_128/00950.png
#   inflating: faces_128/faces_128/00951.png
#   inflating: faces_128/faces_128/00952.png
#   inflating: faces_128/faces_128/00953.png
#   inflating: faces_128/faces_128/00954.png
#   inflating: faces_128/faces_128/00955.png
#   inflating: faces_128/faces_128/00956.png
#   inflating: faces_128/faces_128/00957.png
#   inflating: faces_128/faces_128/00958.png
#   inflating: faces_128/faces_128/00959.png
#   inflating: faces_128/faces_128/00960.png
#   inflating: faces_128/faces_128/00961.png
#   inflating: faces_128/faces_128/00962.png
#   inflating: faces_128/faces_128/00963.png
#   inflating: faces_128/faces_128/00964.png
#   inflating: faces_128/faces_128/00965.png
#   inflating: faces_128/faces_128/00966.png
#   inflating: faces_128/faces_128/00967.png
#   inflating: faces_128/faces_128/00968.png
#   inflating: faces_128/faces_128/00969.png
#   inflating: faces_128/faces_128/00970.png
#   inflating: faces_128/faces_128/00971.png
#   inflating: faces_128/faces_128/00972.png
#   inflating: faces_128/faces_128/00973.png
#   inflating: faces_128/faces_128/00974.png
#   inflating: faces_128/faces_128/00975.png
#   inflating: faces_128/faces_128/00976.png
#   inflating: faces_128/faces_128/00977.png
#   inflating: faces_128/faces_128/00978.png
#   inflating: faces_128/faces_128/00979.png
#   inflating: faces_128/faces_128/00980.png
#   inflating: faces_128/faces_128/00981.png
#   inflating: faces_128/faces_128/00982.png
#   inflating: faces_128/faces_128/00983.png
#   inflating: faces_128/faces_128/00984.png
#   inflating: faces_128/faces_128/00985.png
#   inflating: faces_128/faces_128/00986.png
#   inflating: faces_128/faces_128/00987.png
#   inflating: faces_128/faces_128/00988.png
#   inflating: faces_128/faces_128/00989.png
#   inflating: faces_128/faces_128/00990.png
#   inflating: faces_128/faces_128/00991.png
#   inflating: faces_128/faces_128/00992.png
#   inflating: faces_128/faces_128/00993.png
#   inflating: faces_128/faces_128/00994.png
#   inflating: faces_128/faces_128/00995.png
#   inflating: faces_128/faces_128/00996.png
#   inflating: faces_128/faces_128/00997.png
#   inflating: faces_128/faces_128/00998.png
#   inflating: faces_128/faces_128/00999.png
#   inflating: faces_128/faces_128/01169.png
#   inflating: faces_128/faces_128/01175.png
#   inflating: faces_128/faces_128/01176.png
#   inflating: faces_128/faces_128/01177.png
#   inflating: faces_128/faces_128/01178.png
#   inflating: faces_128/faces_128/01179.png
#   inflating: faces_128/faces_128/01180.png
#   inflating: faces_128/faces_128/01181.png
#   inflating: faces_128/faces_128/01182.png
#   inflating: faces_128/faces_128/01183.png
#   inflating: faces_128/faces_128/01184.png
#   inflating: faces_128/faces_128/01185.png
#   inflating: faces_128/faces_128/01186.png
#   inflating: faces_128/faces_128/01187.png
#   inflating: faces_128/faces_128/01188.png
#   inflating: faces_128/faces_128/01189.png
#   inflating: faces_128/faces_128/01190.png
#   inflating: faces_128/faces_128/01191.png
#   inflating: faces_128/faces_128/01192.png
#   inflating: faces_128/faces_128/01193.png
#   inflating: faces_128/faces_128/01194.png
#   inflating: faces_128/faces_128/01195.png
#   inflating: faces_128/faces_128/01196.png
#   inflating: faces_128/faces_128/01197.png
#   inflating: faces_128/faces_128/01198.png
#   inflating: faces_128/faces_128/01199.png
#   inflating: faces_128/faces_128/01209.png
#   inflating: faces_128/faces_128/01210.png
#   inflating: faces_128/faces_128/01211.png
#   inflating: faces_128/faces_128/01212.png
#   inflating: faces_128/faces_128/01213.png
#   inflating: faces_128/faces_128/01214.png
#   inflating: faces_128/faces_128/01215.png
#   inflating: faces_128/faces_128/01216.png
#   inflating: faces_128/faces_128/01217.png
#   inflating: faces_128/faces_128/01218.png
#   inflating: faces_128/faces_128/01219.png
#   inflating: faces_128/faces_128/01220.png
#   inflating: faces_128/faces_128/01221.png
#   inflating: faces_128/faces_128/01222.png
#   inflating: faces_128/faces_128/01223.png
#   inflating: faces_128/faces_128/01224.png
#   inflating: faces_128/faces_128/01225.png
#   inflating: faces_128/faces_128/01226.png
#   inflating: faces_128/faces_128/01227.png
#   inflating: faces_128/faces_128/01228.png
#   inflating: faces_128/faces_128/01229.png
#   inflating: faces_128/faces_128/01230.png
#   inflating: faces_128/faces_128/01231.png
#   inflating: faces_128/faces_128/01232.png
#   inflating: faces_128/faces_128/01233.png
#   inflating: faces_128/faces_128/01234.png
#   inflating: faces_128/faces_128/01235.png
#   inflating: faces_128/faces_128/01236.png
#   inflating: faces_128/faces_128/01237.png
#   inflating: faces_128/faces_128/01238.png
#   inflating: faces_128/faces_128/01239.png
#   inflating: faces_128/faces_128/01240.png
#   inflating: faces_128/faces_128/01241.png
#   inflating: faces_128/faces_128/01242.png
#   inflating: faces_128/faces_128/01243.png
#   inflating: faces_128/faces_128/01244.png
#   inflating: faces_128/faces_128/01245.png
#   inflating: faces_128/faces_128/01246.png
#   inflating: faces_128/faces_128/01247.png
#   inflating: faces_128/faces_128/01248.png
#   inflating: faces_128/faces_128/01249.png
#   inflating: faces_128/faces_128/01263.png
#   inflating: faces_128/faces_128/01264.png
#   inflating: faces_128/faces_128/01265.png
#   inflating: faces_128/faces_128/01266.png
#   inflating: faces_128/faces_128/01267.png
#   inflating: faces_128/faces_128/01268.png
#   inflating: faces_128/faces_128/01269.png
#   inflating: faces_128/faces_128/01270.png
#   inflating: faces_128/faces_128/01271.png
#   inflating: faces_128/faces_128/01272.png
#   inflating: faces_128/faces_128/01273.png
#   inflating: faces_128/faces_128/01274.png
#   inflating: faces_128/faces_128/01275.png
#   inflating: faces_128/faces_128/01276.png
#   inflating: faces_128/faces_128/01277.png
#   inflating: faces_128/faces_128/01278.png
#   inflating: faces_128/faces_128/01279.png
#   inflating: faces_128/faces_128/01280.png
#   inflating: faces_128/faces_128/01281.png
#   inflating: faces_128/faces_128/01282.png
#   inflating: faces_128/faces_128/01283.png
#   inflating: faces_128/faces_128/01284.png
#   inflating: faces_128/faces_128/01285.png
#   inflating: faces_128/faces_128/01286.png
#   inflating: faces_128/faces_128/01287.png
#   inflating: faces_128/faces_128/01288.png
#   inflating: faces_128/faces_128/01289.png
#   inflating: faces_128/faces_128/01290.png
#   inflating: faces_128/faces_128/01291.png
#   inflating: faces_128/faces_128/01292.png
#   inflating: faces_128/faces_128/01293.png
#   inflating: faces_128/faces_128/01294.png
#   inflating: faces_128/faces_128/01295.png
#   inflating: faces_128/faces_128/01296.png
#   inflating: faces_128/faces_128/01297.png
#   inflating: faces_128/faces_128/01298.png
#   inflating: faces_128/faces_128/01299.png
#   inflating: faces_128/faces_128/01300.png
#   inflating: faces_128/faces_128/01301.png
#   inflating: faces_128/faces_128/01302.png
#   inflating: faces_128/faces_128/01303.png
#   inflating: faces_128/faces_128/01304.png
#   inflating: faces_128/faces_128/01305.png
#   inflating: faces_128/faces_128/01306.png
#   inflating: faces_128/faces_128/01307.png
#   inflating: faces_128/faces_128/01308.png
#   inflating: faces_128/faces_128/01309.png
#   inflating: faces_128/faces_128/01310.png
#   inflating: faces_128/faces_128/01311.png
#   inflating: faces_128/faces_128/01312.png
#   inflating: faces_128/faces_128/01313.png
#   inflating: faces_128/faces_128/01314.png
#   inflating: faces_128/faces_128/01315.png
#   inflating: faces_128/faces_128/01316.png
#   inflating: faces_128/faces_128/01317.png
#   inflating: faces_128/faces_128/01318.png
#   inflating: faces_128/faces_128/01319.png
#   inflating: faces_128/faces_128/01320.png
#   inflating: faces_128/faces_128/01321.png
#   inflating: faces_128/faces_128/01322.png
#   inflating: faces_128/faces_128/01323.png
#   inflating: faces_128/faces_128/01324.png
#   inflating: faces_128/faces_128/01343.png
#   inflating: faces_128/faces_128/01344.png
#   inflating: faces_128/faces_128/01345.png
#   inflating: faces_128/faces_128/01346.png
#   inflating: faces_128/faces_128/01347.png
#   inflating: faces_128/faces_128/01348.png
#   inflating: faces_128/faces_128/01349.png
#   inflating: faces_128/faces_128/01350.png
#   inflating: faces_128/faces_128/01351.png
#   inflating: faces_128/faces_128/01352.png
#   inflating: faces_128/faces_128/01353.png
#   inflating: faces_128/faces_128/01354.png
#   inflating: faces_128/faces_128/01355.png
#   inflating: faces_128/faces_128/01356.png
#   inflating: faces_128/faces_128/01357.png
#   inflating: faces_128/faces_128/01358.png
#   inflating: faces_128/faces_128/01359.png
#   inflating: faces_128/faces_128/01360.png
#   inflating: faces_128/faces_128/01361.png
#   inflating: faces_128/faces_128/01362.png
#   inflating: faces_128/faces_128/01363.png
#   inflating: faces_128/faces_128/01364.png
#   inflating: faces_128/faces_128/01365.png
#   inflating: faces_128/faces_128/01366.png
#   inflating: faces_128/faces_128/01367.png
#   inflating: faces_128/faces_128/01368.png
#   inflating: faces_128/faces_128/01369.png
#   inflating: faces_128/faces_128/01370.png
#   inflating: faces_128/faces_128/01371.png
#   inflating: faces_128/faces_128/01372.png
#   inflating: faces_128/faces_128/01373.png
#   inflating: faces_128/faces_128/01374.png
#   inflating: faces_128/faces_128/01375.png
#   inflating: faces_128/faces_128/01376.png
#   inflating: faces_128/faces_128/01377.png
#   inflating: faces_128/faces_128/01378.png
#   inflating: faces_128/faces_128/01379.png
#   inflating: faces_128/faces_128/01380.png
#   inflating: faces_128/faces_128/01381.png
#   inflating: faces_128/faces_128/01382.png
#   inflating: faces_128/faces_128/01383.png
#   inflating: faces_128/faces_128/01384.png
#   inflating: faces_128/faces_128/01385.png
#   inflating: faces_128/faces_128/01386.png
#   inflating: faces_128/faces_128/01387.png
#   inflating: faces_128/faces_128/01388.png
#   inflating: faces_128/faces_128/01389.png
#   inflating: faces_128/faces_128/01390.png
#   inflating: faces_128/faces_128/01391.png
#   inflating: faces_128/faces_128/01392.png
#   inflating: faces_128/faces_128/01393.png
#   inflating: faces_128/faces_128/01394.png
#   inflating: faces_128/faces_128/01395.png
#   inflating: faces_128/faces_128/01396.png
#   inflating: faces_128/faces_128/01397.png
#   inflating: faces_128/faces_128/01398.png
#   inflating: faces_128/faces_128/01399.png
#   inflating: faces_128/faces_128/01406.png
#   inflating: faces_128/faces_128/01407.png
#   inflating: faces_128/faces_128/01408.png
#   inflating: faces_128/faces_128/01409.png
#   inflating: faces_128/faces_128/01410.png
#   inflating: faces_128/faces_128/01411.png
#   inflating: faces_128/faces_128/01412.png
#   inflating: faces_128/faces_128/01413.png
#   inflating: faces_128/faces_128/01414.png
#   inflating: faces_128/faces_128/01415.png
#   inflating: faces_128/faces_128/01416.png
#   inflating: faces_128/faces_128/01417.png
#   inflating: faces_128/faces_128/01418.png
#   inflating: faces_128/faces_128/01419.png
#   inflating: faces_128/faces_128/01420.png
#   inflating: faces_128/faces_128/01421.png
#   inflating: faces_128/faces_128/01422.png
#   inflating: faces_128/faces_128/01423.png
#   inflating: faces_128/faces_128/01424.png
#   inflating: faces_128/faces_128/01442.png
#   inflating: faces_128/faces_128/01443.png
#   inflating: faces_128/faces_128/01444.png
#   inflating: faces_128/faces_128/01445.png
#   inflating: faces_128/faces_128/01446.png
#   inflating: faces_128/faces_128/01447.png
#   inflating: faces_128/faces_128/01448.png
#   inflating: faces_128/faces_128/01449.png
#   inflating: faces_128/faces_128/01450.png
#   inflating: faces_128/faces_128/01451.png
#   inflating: faces_128/faces_128/01452.png
#   inflating: faces_128/faces_128/01453.png
#   inflating: faces_128/faces_128/01454.png
#   inflating: faces_128/faces_128/01455.png
#   inflating: faces_128/faces_128/01456.png
#   inflating: faces_128/faces_128/01457.png
#   inflating: faces_128/faces_128/01458.png
#   inflating: faces_128/faces_128/01459.png
#   inflating: faces_128/faces_128/01460.png
#   inflating: faces_128/faces_128/01461.png
#   inflating: faces_128/faces_128/01462.png
#   inflating: faces_128/faces_128/01463.png
#   inflating: faces_128/faces_128/01464.png
#   inflating: faces_128/faces_128/01465.png
#   inflating: faces_128/faces_128/01466.png
#   inflating: faces_128/faces_128/01467.png
#   inflating: faces_128/faces_128/01468.png
#   inflating: faces_128/faces_128/01469.png
#   inflating: faces_128/faces_128/01470.png
#   inflating: faces_128/faces_128/01471.png
#   inflating: faces_128/faces_128/01472.png
#   inflating: faces_128/faces_128/01473.png
#   inflating: faces_128/faces_128/01474.png
#   inflating: faces_128/faces_128/01475.png
#   inflating: faces_128/faces_128/01476.png
#   inflating: faces_128/faces_128/01477.png
#   inflating: faces_128/faces_128/01478.png
#   inflating: faces_128/faces_128/01479.png
#   inflating: faces_128/faces_128/01480.png
#   inflating: faces_128/faces_128/01481.png
#   inflating: faces_128/faces_128/01482.png
#   inflating: faces_128/faces_128/01483.png
#   inflating: faces_128/faces_128/01484.png
#   inflating: faces_128/faces_128/01485.png
#   inflating: faces_128/faces_128/01486.png
#   inflating: faces_128/faces_128/01487.png
#   inflating: faces_128/faces_128/01488.png
#   inflating: faces_128/faces_128/01489.png
#   inflating: faces_128/faces_128/01490.png
#   inflating: faces_128/faces_128/01491.png
#   inflating: faces_128/faces_128/01492.png
#   inflating: faces_128/faces_128/01493.png
#   inflating: faces_128/faces_128/01494.png
#   inflating: faces_128/faces_128/01495.png
#   inflating: faces_128/faces_128/01496.png
#   inflating: faces_128/faces_128/01497.png
#   inflating: faces_128/faces_128/01498.png
#   inflating: faces_128/faces_128/01499.png
#   inflating: faces_128/faces_128/01525.png
#   inflating: faces_128/faces_128/01526.png
#   inflating: faces_128/faces_128/01527.png
#   inflating: faces_128/faces_128/01528.png
#   inflating: faces_128/faces_128/01529.png
#   inflating: faces_128/faces_128/01530.png
#   inflating: faces_128/faces_128/01531.png
#   inflating: faces_128/faces_128/01532.png
#   inflating: faces_128/faces_128/01533.png
#   inflating: faces_128/faces_128/01534.png
#   inflating: faces_128/faces_128/01535.png
#   inflating: faces_128/faces_128/01536.png
#   inflating: faces_128/faces_128/01537.png
#   inflating: faces_128/faces_128/01538.png
#   inflating: faces_128/faces_128/01539.png
#   inflating: faces_128/faces_128/01540.png
#   inflating: faces_128/faces_128/01541.png
#   inflating: faces_128/faces_128/01542.png
#   inflating: faces_128/faces_128/01543.png
#   inflating: faces_128/faces_128/01544.png
#   inflating: faces_128/faces_128/01545.png
#   inflating: faces_128/faces_128/01546.png
#   inflating: faces_128/faces_128/01547.png
#   inflating: faces_128/faces_128/01548.png
#   inflating: faces_128/faces_128/01549.png
#   inflating: faces_128/faces_128/01550.png
#   inflating: faces_128/faces_128/01551.png
#   inflating: faces_128/faces_128/01552.png
#   inflating: faces_128/faces_128/01553.png
#   inflating: faces_128/faces_128/01554.png
#   inflating: faces_128/faces_128/01555.png
#   inflating: faces_128/faces_128/01556.png
#   inflating: faces_128/faces_128/01557.png
#   inflating: faces_128/faces_128/01558.png
#   inflating: faces_128/faces_128/01559.png
#   inflating: faces_128/faces_128/01560.png
#   inflating: faces_128/faces_128/01561.png
#   inflating: faces_128/faces_128/01562.png
#   inflating: faces_128/faces_128/01563.png
#   inflating: faces_128/faces_128/01564.png
#   inflating: faces_128/faces_128/01565.png
#   inflating: faces_128/faces_128/01566.png
#   inflating: faces_128/faces_128/01567.png
#   inflating: faces_128/faces_128/01568.png
#   inflating: faces_128/faces_128/01569.png
#   inflating: faces_128/faces_128/01570.png
#   inflating: faces_128/faces_128/01571.png
#   inflating: faces_128/faces_128/01572.png
#   inflating: faces_128/faces_128/01573.png
#   inflating: faces_128/faces_128/01574.png
#   inflating: faces_128/faces_128/01575.png
#   inflating: faces_128/faces_128/01576.png
#   inflating: faces_128/faces_128/01577.png
#   inflating: faces_128/faces_128/01578.png
#   inflating: faces_128/faces_128/01579.png
#   inflating: faces_128/faces_128/01580.png
#   inflating: faces_128/faces_128/01581.png
#   inflating: faces_128/faces_128/01582.png
#   inflating: faces_128/faces_128/01583.png
#   inflating: faces_128/faces_128/01584.png
#   inflating: faces_128/faces_128/01585.png
#   inflating: faces_128/faces_128/01586.png
#   inflating: faces_128/faces_128/01587.png
#   inflating: faces_128/faces_128/01588.png
#   inflating: faces_128/faces_128/01589.png
#   inflating: faces_128/faces_128/01590.png
#   inflating: faces_128/faces_128/01591.png
#   inflating: faces_128/faces_128/01592.png
#   inflating: faces_128/faces_128/01593.png
#   inflating: faces_128/faces_128/01594.png
#   inflating: faces_128/faces_128/01595.png
#   inflating: faces_128/faces_128/01596.png
#   inflating: faces_128/faces_128/01597.png
#   inflating: faces_128/faces_128/01598.png
#   inflating: faces_128/faces_128/01599.png
#   inflating: faces_128/faces_128/01600.png
#   inflating: faces_128/faces_128/01601.png
#   inflating: faces_128/faces_128/01602.png
#   inflating: faces_128/faces_128/01603.png
#   inflating: faces_128/faces_128/01604.png
#   inflating: faces_128/faces_128/01605.png
#   inflating: faces_128/faces_128/01606.png
#   inflating: faces_128/faces_128/01607.png
#   inflating: faces_128/faces_128/01608.png
#   inflating: faces_128/faces_128/01609.png
#   inflating: faces_128/faces_128/01610.png
#   inflating: faces_128/faces_128/01611.png
#   inflating: faces_128/faces_128/01612.png
#   inflating: faces_128/faces_128/01613.png
#   inflating: faces_128/faces_128/01614.png
#   inflating: faces_128/faces_128/01615.png
#   inflating: faces_128/faces_128/01616.png
#   inflating: faces_128/faces_128/01617.png
#   inflating: faces_128/faces_128/01618.png
#   inflating: faces_128/faces_128/01619.png
#   inflating: faces_128/faces_128/01620.png
#   inflating: faces_128/faces_128/01621.png
#   inflating: faces_128/faces_128/01622.png
#   inflating: faces_128/faces_128/01623.png
#   inflating: faces_128/faces_128/01624.png
#   inflating: faces_128/faces_128/01625.png
#   inflating: faces_128/faces_128/01626.png
#   inflating: faces_128/faces_128/01627.png
#   inflating: faces_128/faces_128/01628.png
#   inflating: faces_128/faces_128/01629.png
#   inflating: faces_128/faces_128/01630.png
#   inflating: faces_128/faces_128/01631.png
#   inflating: faces_128/faces_128/01632.png
#   inflating: faces_128/faces_128/01633.png
#   inflating: faces_128/faces_128/01634.png
#   inflating: faces_128/faces_128/01635.png
#   inflating: faces_128/faces_128/01636.png
#   inflating: faces_128/faces_128/01637.png
#   inflating: faces_128/faces_128/01638.png
#   inflating: faces_128/faces_128/01639.png
#   inflating: faces_128/faces_128/01640.png
#   inflating: faces_128/faces_128/01641.png
#   inflating: faces_128/faces_128/01642.png
#   inflating: faces_128/faces_128/01643.png
#   inflating: faces_128/faces_128/01644.png
#   inflating: faces_128/faces_128/01645.png
#   inflating: faces_128/faces_128/01646.png
#   inflating: faces_128/faces_128/01647.png
#   inflating: faces_128/faces_128/01648.png
#   inflating: faces_128/faces_128/01649.png
#   inflating: faces_128/faces_128/01675.png
#   inflating: faces_128/faces_128/01676.png
#   inflating: faces_128/faces_128/01677.png
#   inflating: faces_128/faces_128/01678.png
#   inflating: faces_128/faces_128/01679.png
#   inflating: faces_128/faces_128/01680.png
#   inflating: faces_128/faces_128/01681.png
#   inflating: faces_128/faces_128/01682.png
#   inflating: faces_128/faces_128/01683.png
#   inflating: faces_128/faces_128/01684.png
#   inflating: faces_128/faces_128/01685.png
#   inflating: faces_128/faces_128/01686.png
#   inflating: faces_128/faces_128/01687.png
#   inflating: faces_128/faces_128/01688.png
#   inflating: faces_128/faces_128/01689.png
#   inflating: faces_128/faces_128/01690.png
#   inflating: faces_128/faces_128/01691.png
#   inflating: faces_128/faces_128/01692.png
#   inflating: faces_128/faces_128/01693.png
#   inflating: faces_128/faces_128/01694.png
#   inflating: faces_128/faces_128/01695.png
#   inflating: faces_128/faces_128/01696.png
#   inflating: faces_128/faces_128/01697.png
#   inflating: faces_128/faces_128/01698.png
#   inflating: faces_128/faces_128/01699.png
#   inflating: faces_128/faces_128/01700.png
#   inflating: faces_128/faces_128/01701.png
#   inflating: faces_128/faces_128/01702.png
#   inflating: faces_128/faces_128/01703.png
#   inflating: faces_128/faces_128/01704.png
#   inflating: faces_128/faces_128/01705.png
#   inflating: faces_128/faces_128/01706.png
#   inflating: faces_128/faces_128/01707.png
#   inflating: faces_128/faces_128/01708.png
#   inflating: faces_128/faces_128/01709.png
#   inflating: faces_128/faces_128/01710.png
#   inflating: faces_128/faces_128/01711.png
#   inflating: faces_128/faces_128/01712.png
#   inflating: faces_128/faces_128/01713.png
#   inflating: faces_128/faces_128/01714.png
#   inflating: faces_128/faces_128/01715.png
#   inflating: faces_128/faces_128/01716.png
#   inflating: faces_128/faces_128/01717.png
#   inflating: faces_128/faces_128/01718.png
#   inflating: faces_128/faces_128/01719.png
#   inflating: faces_128/faces_128/01720.png
#   inflating: faces_128/faces_128/01721.png
#   inflating: faces_128/faces_128/01722.png
#   inflating: faces_128/faces_128/01723.png
#   inflating: faces_128/faces_128/01724.png
#   inflating: faces_128/faces_128/01750.png
#   inflating: faces_128/faces_128/01751.png
#   inflating: faces_128/faces_128/01752.png
#   inflating: faces_128/faces_128/01753.png
#   inflating: faces_128/faces_128/01754.png
#   inflating: faces_128/faces_128/01755.png
#   inflating: faces_128/faces_128/01756.png
#   inflating: faces_128/faces_128/01757.png
#   inflating: faces_128/faces_128/01758.png
#   inflating: faces_128/faces_128/01759.png
#   inflating: faces_128/faces_128/01760.png
#   inflating: faces_128/faces_128/01761.png
#   inflating: faces_128/faces_128/01762.png
#   inflating: faces_128/faces_128/01763.png
#   inflating: faces_128/faces_128/01764.png
#   inflating: faces_128/faces_128/01765.png
#   inflating: faces_128/faces_128/01766.png
#   inflating: faces_128/faces_128/01767.png
#   inflating: faces_128/faces_128/01768.png
#   inflating: faces_128/faces_128/01769.png
#   inflating: faces_128/faces_128/01770.png
#   inflating: faces_128/faces_128/01771.png
#   inflating: faces_128/faces_128/01772.png
#   inflating: faces_128/faces_128/01773.png
#   inflating: faces_128/faces_128/01774.png
#   inflating: faces_128/faces_128/01775.png
#   inflating: faces_128/faces_128/01776.png
#   inflating: faces_128/faces_128/01777.png
#   inflating: faces_128/faces_128/01778.png
#   inflating: faces_128/faces_128/01779.png
#   inflating: faces_128/faces_128/01780.png
#   inflating: faces_128/faces_128/01781.png
#   inflating: faces_128/faces_128/01782.png
#   inflating: faces_128/faces_128/01783.png
#   inflating: faces_128/faces_128/01784.png
#   inflating: faces_128/faces_128/01785.png
#   inflating: faces_128/faces_128/01786.png
#   inflating: faces_128/faces_128/01787.png
#   inflating: faces_128/faces_128/01788.png
#   inflating: faces_128/faces_128/01789.png
#   inflating: faces_128/faces_128/01790.png
#   inflating: faces_128/faces_128/01791.png
#   inflating: faces_128/faces_128/01792.png
#   inflating: faces_128/faces_128/01793.png
#   inflating: faces_128/faces_128/01794.png
#   inflating: faces_128/faces_128/01795.png
#   inflating: faces_128/faces_128/01796.png
#   inflating: faces_128/faces_128/01797.png
#   inflating: faces_128/faces_128/01798.png
#   inflating: faces_128/faces_128/01799.png
#   inflating: faces_128/faces_128/01800.png
#   inflating: faces_128/faces_128/01801.png
#   inflating: faces_128/faces_128/01802.png
#   inflating: faces_128/faces_128/01803.png
#   inflating: faces_128/faces_128/01804.png
#   inflating: faces_128/faces_128/01805.png
#   inflating: faces_128/faces_128/01806.png
#   inflating: faces_128/faces_128/01807.png
#   inflating: faces_128/faces_128/01808.png
#   inflating: faces_128/faces_128/01809.png
#   inflating: faces_128/faces_128/01810.png
#   inflating: faces_128/faces_128/01811.png
#   inflating: faces_128/faces_128/01812.png
#   inflating: faces_128/faces_128/01813.png
#   inflating: faces_128/faces_128/01814.png
#   inflating: faces_128/faces_128/01815.png
#   inflating: faces_128/faces_128/01816.png
#   inflating: faces_128/faces_128/01817.png
# ...
#   inflating: faces_128/faces_128/04619.png
#   inflating: faces_128/faces_128/04620.png
#   inflating: faces_128/faces_128/04621.png
#   inflating: faces_128/faces_128/04622.png
#   inflating: faces_128/faces_128/04623.png
#   inflating: faces_128/faces_128/04624.png
#   inflating: faces_128/faces_128/04625.png
#   inflating: faces_128/faces_128/04626.png
#   inflating: faces_128/faces_128/04627.png
#   inflating: faces_128/faces_128/04628.png
#   inflating: faces_128/faces_128/04629.png
#   inflating: faces_128/faces_128/04630.png
#   inflating: faces_128/faces_128/04631.png
#   inflating: faces_128/faces_128/04632.png
#   inflating: faces_128/faces_128/04633.png
#   inflating: faces_128/faces_128/04634.png
#   inflating: faces_128/faces_128/04635.png
#   inflating: faces_128/faces_128/04636.png
#   inflating: faces_128/faces_128/04637.png
#   inflating: faces_128/faces_128/04638.png
#   inflating: faces_128/faces_128/04639.png
#   inflating: faces_128/faces_128/04640.png
#   inflating: faces_128/faces_128/04641.png
#   inflating: faces_128/faces_128/04642.png
#   inflating: faces_128/faces_128/04643.png
#   inflating: faces_128/faces_128/04644.png
#   inflating: faces_128/faces_128/04645.png
#   inflating: faces_128/faces_128/04646.png
#   inflating: faces_128/faces_128/04647.png
#   inflating: faces_128/faces_128/04648.png
#   inflating: faces_128/faces_128/04649.png
#   inflating: faces_128/faces_128/04653.png
#   inflating: faces_128/faces_128/04669.png
#   inflating: faces_128/faces_128/04670.png
#   inflating: faces_128/faces_128/04671.png
#   inflating: faces_128/faces_128/04672.png
#   inflating: faces_128/faces_128/04673.png
#   inflating: faces_128/faces_128/04674.png
#   inflating: faces_128/faces_128/04675.png
#   inflating: faces_128/faces_128/04676.png
#   inflating: faces_128/faces_128/04677.png
#   inflating: faces_128/faces_128/04678.png
#   inflating: faces_128/faces_128/04679.png
#   inflating: faces_128/faces_128/04680.png
#   inflating: faces_128/faces_128/04681.png
#   inflating: faces_128/faces_128/04682.png
#   inflating: faces_128/faces_128/04683.png
#   inflating: faces_128/faces_128/04684.png
#   inflating: faces_128/faces_128/04685.png
#   inflating: faces_128/faces_128/04686.png
#   inflating: faces_128/faces_128/04687.png
#   inflating: faces_128/faces_128/04688.png
#   inflating: faces_128/faces_128/04689.png
#   inflating: faces_128/faces_128/04690.png
#   inflating: faces_128/faces_128/04691.png
#   inflating: faces_128/faces_128/04692.png
#   inflating: faces_128/faces_128/04693.png
#   inflating: faces_128/faces_128/04694.png
#   inflating: faces_128/faces_128/04695.png
#   inflating: faces_128/faces_128/04696.png
#   inflating: faces_128/faces_128/04697.png
#   inflating: faces_128/faces_128/04698.png
#   inflating: faces_128/faces_128/04699.png
#   inflating: faces_128/faces_128/04708.png
#   inflating: faces_128/faces_128/04709.png
#   inflating: faces_128/faces_128/04710.png
#   inflating: faces_128/faces_128/04711.png
#   inflating: faces_128/faces_128/04712.png
#   inflating: faces_128/faces_128/04713.png
#   inflating: faces_128/faces_128/04714.png
#   inflating: faces_128/faces_128/04715.png
#   inflating: faces_128/faces_128/04716.png
#   inflating: faces_128/faces_128/04717.png
#   inflating: faces_128/faces_128/04718.png
#   inflating: faces_128/faces_128/04719.png
#   inflating: faces_128/faces_128/04720.png
#   inflating: faces_128/faces_128/04721.png
#   inflating: faces_128/faces_128/04722.png
#   inflating: faces_128/faces_128/04723.png
#   inflating: faces_128/faces_128/04724.png
#   inflating: faces_128/faces_128/04725.png
#   inflating: faces_128/faces_128/04726.png
#   inflating: faces_128/faces_128/04727.png
#   inflating: faces_128/faces_128/04728.png
#   inflating: faces_128/faces_128/04729.png
#   inflating: faces_128/faces_128/04730.png
#   inflating: faces_128/faces_128/04731.png
#   inflating: faces_128/faces_128/04732.png
#   inflating: faces_128/faces_128/04733.png
#   inflating: faces_128/faces_128/04734.png
#   inflating: faces_128/faces_128/04735.png
#   inflating: faces_128/faces_128/04736.png
#   inflating: faces_128/faces_128/04737.png
#   inflating: faces_128/faces_128/04738.png
#   inflating: faces_128/faces_128/04739.png
#   inflating: faces_128/faces_128/04740.png
#   inflating: faces_128/faces_128/04741.png
#   inflating: faces_128/faces_128/04742.png
#   inflating: faces_128/faces_128/04743.png
#   inflating: faces_128/faces_128/04744.png
#   inflating: faces_128/faces_128/04745.png
#   inflating: faces_128/faces_128/04746.png
#   inflating: faces_128/faces_128/04747.png
#   inflating: faces_128/faces_128/04748.png
#   inflating: faces_128/faces_128/04749.png
#   inflating: faces_128/faces_128/04750.png
#   inflating: faces_128/faces_128/04751.png
#   inflating: faces_128/faces_128/04752.png
#   inflating: faces_128/faces_128/04753.png
#   inflating: faces_128/faces_128/04754.png
#   inflating: faces_128/faces_128/04755.png
#   inflating: faces_128/faces_128/04756.png
#   inflating: faces_128/faces_128/04757.png
#   inflating: faces_128/faces_128/04758.png
#   inflating: faces_128/faces_128/04759.png
#   inflating: faces_128/faces_128/04760.png
#   inflating: faces_128/faces_128/04761.png
#   inflating: faces_128/faces_128/04762.png
#   inflating: faces_128/faces_128/04763.png
#   inflating: faces_128/faces_128/04764.png
#   inflating: faces_128/faces_128/04765.png
#   inflating: faces_128/faces_128/04766.png
#   inflating: faces_128/faces_128/04767.png
#   inflating: faces_128/faces_128/04768.png
#   inflating: faces_128/faces_128/04769.png
#   inflating: faces_128/faces_128/04770.png
#   inflating: faces_128/faces_128/04771.png
#   inflating: faces_128/faces_128/04772.png
#   inflating: faces_128/faces_128/04773.png
#   inflating: faces_128/faces_128/04774.png
#   inflating: faces_128/faces_128/04775.png
#   inflating: faces_128/faces_128/04776.png
#   inflating: faces_128/faces_128/04777.png
#   inflating: faces_128/faces_128/04778.png
#   inflating: faces_128/faces_128/04779.png
#   inflating: faces_128/faces_128/04780.png
#   inflating: faces_128/faces_128/04781.png
#   inflating: faces_128/faces_128/04782.png
#   inflating: faces_128/faces_128/04783.png
#   inflating: faces_128/faces_128/04784.png
#   inflating: faces_128/faces_128/04785.png
#   inflating: faces_128/faces_128/04786.png
#   inflating: faces_128/faces_128/04787.png
#   inflating: faces_128/faces_128/04788.png
#   inflating: faces_128/faces_128/04789.png
#   inflating: faces_128/faces_128/04790.png
#   inflating: faces_128/faces_128/04791.png
#   inflating: faces_128/faces_128/04792.png
#   inflating: faces_128/faces_128/04793.png
#   inflating: faces_128/faces_128/04794.png
#   inflating: faces_128/faces_128/04795.png
#   inflating: faces_128/faces_128/04796.png
#   inflating: faces_128/faces_128/04797.png
#   inflating: faces_128/faces_128/04798.png
#   inflating: faces_128/faces_128/04799.png
#   inflating: faces_128/faces_128/04800.png
#   inflating: faces_128/faces_128/04801.png
#   inflating: faces_128/faces_128/04802.png
#   inflating: faces_128/faces_128/04803.png
#   inflating: faces_128/faces_128/04804.png
#   inflating: faces_128/faces_128/04805.png
#   inflating: faces_128/faces_128/04806.png
#   inflating: faces_128/faces_128/04807.png
#   inflating: faces_128/faces_128/04808.png
#   inflating: faces_128/faces_128/04809.png
#   inflating: faces_128/faces_128/04810.png
#   inflating: faces_128/faces_128/04811.png
#   inflating: faces_128/faces_128/04812.png
#   inflating: faces_128/faces_128/04813.png
#   inflating: faces_128/faces_128/04814.png
#   inflating: faces_128/faces_128/04815.png
#   inflating: faces_128/faces_128/04816.png
#   inflating: faces_128/faces_128/04817.png
#   inflating: faces_128/faces_128/04818.png
#   inflating: faces_128/faces_128/04819.png
#   inflating: faces_128/faces_128/04820.png
#   inflating: faces_128/faces_128/04821.png
#   inflating: faces_128/faces_128/04822.png
#   inflating: faces_128/faces_128/04823.png
#   inflating: faces_128/faces_128/04824.png
#   inflating: faces_128/faces_128/04825.png
#   inflating: faces_128/faces_128/04826.png
#   inflating: faces_128/faces_128/04827.png
#   inflating: faces_128/faces_128/04828.png
#   inflating: faces_128/faces_128/04829.png
#   inflating: faces_128/faces_128/04830.png
#   inflating: faces_128/faces_128/04831.png
#   inflating: faces_128/faces_128/04832.png
#   inflating: faces_128/faces_128/04833.png
#   inflating: faces_128/faces_128/04834.png
#   inflating: faces_128/faces_128/04835.png
#   inflating: faces_128/faces_128/04836.png
#   inflating: faces_128/faces_128/04837.png
#   inflating: faces_128/faces_128/04838.png
#   inflating: faces_128/faces_128/04839.png
#   inflating: faces_128/faces_128/04840.png
#   inflating: faces_128/faces_128/04841.png
#   inflating: faces_128/faces_128/04842.png
#   inflating: faces_128/faces_128/04843.png
#   inflating: faces_128/faces_128/04844.png
#   inflating: faces_128/faces_128/04845.png
#   inflating: faces_128/faces_128/04846.png
#   inflating: faces_128/faces_128/04847.png
#   inflating: faces_128/faces_128/04848.png
#   inflating: faces_128/faces_128/04849.png
#   inflating: faces_128/faces_128/04850.png
#   inflating: faces_128/faces_128/04851.png
#   inflating: faces_128/faces_128/04852.png
#   inflating: faces_128/faces_128/04853.png
#   inflating: faces_128/faces_128/04854.png
#   inflating: faces_128/faces_128/04855.png
#   inflating: faces_128/faces_128/04856.png
#   inflating: faces_128/faces_128/04857.png
#   inflating: faces_128/faces_128/04858.png
#   inflating: faces_128/faces_128/04859.png
#   inflating: faces_128/faces_128/04860.png
#   inflating: faces_128/faces_128/04861.png
#   inflating: faces_128/faces_128/04862.png
#   inflating: faces_128/faces_128/04863.png
#   inflating: faces_128/faces_128/04864.png
#   inflating: faces_128/faces_128/04865.png
#   inflating: faces_128/faces_128/04866.png
#   inflating: faces_128/faces_128/04867.png
#   inflating: faces_128/faces_128/04868.png
#   inflating: faces_128/faces_128/04869.png
#   inflating: faces_128/faces_128/04870.png
#   inflating: faces_128/faces_128/04871.png
#   inflating: faces_128/faces_128/04872.png
#   inflating: faces_128/faces_128/04873.png
#   inflating: faces_128/faces_128/04874.png
#   inflating: faces_128/faces_128/04875.png
#   inflating: faces_128/faces_128/04876.png
#   inflating: faces_128/faces_128/04877.png
#   inflating: faces_128/faces_128/04878.png
#   inflating: faces_128/faces_128/04879.png
#   inflating: faces_128/faces_128/04880.png
#   inflating: faces_128/faces_128/04881.png
#   inflating: faces_128/faces_128/04882.png
#   inflating: faces_128/faces_128/04883.png
#   inflating: faces_128/faces_128/04884.png
#   inflating: faces_128/faces_128/04885.png
#   inflating: faces_128/faces_128/04886.png
#   inflating: faces_128/faces_128/04887.png
#   inflating: faces_128/faces_128/04888.png
#   inflating: faces_128/faces_128/04889.png
#   inflating: faces_128/faces_128/04890.png
#   inflating: faces_128/faces_128/04891.png
#   inflating: faces_128/faces_128/04892.png
#   inflating: faces_128/faces_128/04893.png
#   inflating: faces_128/faces_128/04894.png
#   inflating: faces_128/faces_128/04895.png
#   inflating: faces_128/faces_128/04896.png
#   inflating: faces_128/faces_128/04897.png
#   inflating: faces_128/faces_128/04898.png
#   inflating: faces_128/faces_128/04899.png
#   inflating: faces_128/faces_128/04900.png
#   inflating: faces_128/faces_128/04901.png
#   inflating: faces_128/faces_128/04902.png
#   inflating: faces_128/faces_128/04903.png
#   inflating: faces_128/faces_128/04904.png
#   inflating: faces_128/faces_128/04905.png
#   inflating: faces_128/faces_128/04906.png
#   inflating: faces_128/faces_128/04907.png
#   inflating: faces_128/faces_128/04908.png
#   inflating: faces_128/faces_128/04909.png
#   inflating: faces_128/faces_128/04910.png
#   inflating: faces_128/faces_128/04911.png
#   inflating: faces_128/faces_128/04912.png
#   inflating: faces_128/faces_128/04913.png
#   inflating: faces_128/faces_128/04914.png
#   inflating: faces_128/faces_128/04915.png
#   inflating: faces_128/faces_128/04916.png
#   inflating: faces_128/faces_128/04917.png
#   inflating: faces_128/faces_128/04918.png
#   inflating: faces_128/faces_128/04919.png
#   inflating: faces_128/faces_128/04920.png
#   inflating: faces_128/faces_128/04921.png
#   inflating: faces_128/faces_128/04922.png
#   inflating: faces_128/faces_128/04923.png
#   inflating: faces_128/faces_128/04924.png
#   inflating: faces_128/faces_128/04925.png
#   inflating: faces_128/faces_128/04926.png
#   inflating: faces_128/faces_128/04927.png
#   inflating: faces_128/faces_128/04928.png
#   inflating: faces_128/faces_128/04929.png
#   inflating: faces_128/faces_128/04930.png
#   inflating: faces_128/faces_128/04931.png
#   inflating: faces_128/faces_128/04932.png
#   inflating: faces_128/faces_128/04933.png
#   inflating: faces_128/faces_128/04934.png
#   inflating: faces_128/faces_128/04935.png
#   inflating: faces_128/faces_128/04936.png
#   inflating: faces_128/faces_128/04937.png
#   inflating: faces_128/faces_128/04938.png
#   inflating: faces_128/faces_128/04939.png
#   inflating: faces_128/faces_128/04940.png
#   inflating: faces_128/faces_128/04941.png
#   inflating: faces_128/faces_128/04942.png
#   inflating: faces_128/faces_128/04943.png
#   inflating: faces_128/faces_128/04944.png
#   inflating: faces_128/faces_128/04945.png
#   inflating: faces_128/faces_128/04946.png
#   inflating: faces_128/faces_128/04947.png
#   inflating: faces_128/faces_128/04948.png
#   inflating: faces_128/faces_128/04949.png
#   inflating: faces_128/faces_128/04950.png
#   inflating: faces_128/faces_128/04951.png
#   inflating: faces_128/faces_128/04952.png
#   inflating: faces_128/faces_128/04953.png
#   inflating: faces_128/faces_128/04954.png
#   inflating: faces_128/faces_128/04955.png
#   inflating: faces_128/faces_128/04956.png
#   inflating: faces_128/faces_128/04957.png
#   inflating: faces_128/faces_128/04958.png
#   inflating: faces_128/faces_128/04959.png
#   inflating: faces_128/faces_128/04960.png
#   inflating: faces_128/faces_128/04961.png
#   inflating: faces_128/faces_128/04962.png
#   inflating: faces_128/faces_128/04963.png
#   inflating: faces_128/faces_128/04964.png
#   inflating: faces_128/faces_128/04965.png
#   inflating: faces_128/faces_128/04966.png
#   inflating: faces_128/faces_128/04967.png
#   inflating: faces_128/faces_128/04968.png
#   inflating: faces_128/faces_128/04969.png
#   inflating: faces_128/faces_128/04970.png
#   inflating: faces_128/faces_128/04971.png
#   inflating: faces_128/faces_128/04972.png
#   inflating: faces_128/faces_128/04973.png
#   inflating: faces_128/faces_128/04974.png
#   inflating: faces_128/faces_128/04975.png
#   inflating: faces_128/faces_128/04976.png
#   inflating: faces_128/faces_128/04977.png
#   inflating: faces_128/faces_128/04978.png
#   inflating: faces_128/faces_128/04979.png
#   inflating: faces_128/faces_128/04980.png
#   inflating: faces_128/faces_128/04981.png
#   inflating: faces_128/faces_128/04982.png
#   inflating: faces_128/faces_128/04983.png
#   inflating: faces_128/faces_128/04984.png
#   inflating: faces_128/faces_128/04985.png
#   inflating: faces_128/faces_128/04986.png
#   inflating: faces_128/faces_128/04987.png
#   inflating: faces_128/faces_128/04988.png
#   inflating: faces_128/faces_128/04989.png
#   inflating: faces_128/faces_128/04990.png
#   inflating: faces_128/faces_128/04991.png
#   inflating: faces_128/faces_128/04992.png
#   inflating: faces_128/faces_128/04993.png
#   inflating: faces_128/faces_128/04994.png
#   inflating: faces_128/faces_128/04995.png
#   inflating: faces_128/faces_128/04996.png
#   inflating: faces_128/faces_128/04997.png
#   inflating: faces_128/faces_128/04998.png
#   inflating: faces_128/faces_128/04999.png

# %%
DATA_PATH = 'C:\\prj\\DLS\\data\\faces_dataset_small'
# DATA_PATH_128 = 'C:\\prj\\DLS\\data\\faces_128'
DATA_PATH_128 = '/content/faces_128/faces_128'

# %%
import os
from PIL import Image


os.makedirs(DATA_PATH_128, exist_ok=True)

for filename in os.listdir(DATA_PATH):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        try:
            img_path = os.path.join(DATA_PATH, filename)
            img = Image.open(img_path)

            img_resized = img.resize((128, 128), Image.LANCZOS)

            output_path = os.path.join(DATA_PATH_128, filename)
            img_resized.save(output_path)

            print(f"Processed: {filename}")
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")

print("All images have been resized")

# %%
import os
from torch.utils.data import Dataset
from PIL import Image

class FlatImageFolder(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_files = [f for f in os.listdir(root_dir)
                           if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.image_files[idx])
        image = Image.open(img_path)

        if self.transform:
            image = self.transform(image)

        # Возвращаем image и пустой label (0)
        return image

def get_dataloader(batch_size):
    """
    Builds dataloader for training data.
    :param batch_size: batch_size of the dataloader
    :returns: DataLoader object
    """
    transform = tt.Compose([
        # tt.Resize((128, 128)),  # Явно указываем размер
        tt.ToTensor(),
    ])

    # Используем наш FlatImageFolder вместо ImageFolder
    dataset = FlatImageFolder(root_dir=DATA_PATH_128, transform=transform)

    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        # num_workers=2
    )

    return dataloader

def show_images(dataloader, num_images=5):
    images = next(iter(dataloader))  # Игнорируем labels

    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    for i in range(num_images):
        img = images[i].numpy().transpose((1, 2, 0))
        # Для изображений с нормализацией может потребоваться обратная нормализация
        img = np.clip(img, 0, 1)  # Обеспечиваем корректный диапазон значений
        axes[i].imshow(img)
        axes[i].axis('off')
    plt.show()

# %%
batch_size = 32
dataloader = get_dataloader(batch_size)
show_images(dataloader, 5)

# %%
image_size = 128

#TODO: build dataloader and transfer it to device

# %% [markdown]
# ## Часть 2. Построение и обучение модели (2 балла)

# %% [markdown]
# Сконструируйте генератор и дискриминатор. Помните, что:
# * дискриминатор принимает на вход изображение (тензор размера `3 x image_size x image_size`) и выдает вероятность того, что изображение настоящее (тензор размера 1)
#
# * генератор принимает на вход тензор шумов размера `latent_size x 1 x 1` и генерирует изображение размера `3 x image_size x image_size`

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
import torch
import torch.nn as nn

# Размеры
image_size = 128
latent_size = 100
n_channels = 3  # RGB
nf = 64  # Число фильтров в первом слое

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.main = nn.Sequential(
            # Вход: latent_size x 1 x 1
            nn.ConvTranspose2d(latent_size, nf * 16, 4, 1, 0, bias=False),
            nn.BatchNorm2d(nf * 16),
            nn.ReLU(True),
            # 4x4

            nn.ConvTranspose2d(nf * 16, nf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf * 8),
            nn.ReLU(True),
            # 8x8

            nn.ConvTranspose2d(nf * 8, nf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf * 4),
            nn.ReLU(True),
            # 16x16

            nn.ConvTranspose2d(nf * 4, nf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf * 2),
            nn.ReLU(True),
            # 32x32

            nn.ConvTranspose2d(nf * 2, nf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf),
            nn.ReLU(True),
            # 64x64

            nn.ConvTranspose2d(nf, n_channels, 4, 2, 1, bias=False),
            nn.Tanh()
            # 128x128
        )

    def forward(self, input):
        return self.main(input)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.main = nn.Sequential(
            # Вход: 3 x 128 x 128
            nn.Conv2d(n_channels, nf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # 64x64

            nn.Conv2d(nf, nf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # 32x32

            nn.Conv2d(nf * 2, nf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # 16x16

            nn.Conv2d(nf * 4, nf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # 8x8

            nn.Conv2d(nf * 8, nf * 16, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nf * 16),
            nn.LeakyReLU(0.2, inplace=True),
            # 4x4

            nn.Conv2d(nf * 16, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input).view(-1, 1).squeeze(1)

# Инициализация моделей
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# Создаем экземпляры моделей
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Инициализируем веса
generator.apply(weights_init)
discriminator.apply(weights_init)

# Выводим архитектуру
print(generator)
print(discriminator)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU(inplace=True)
#     (15): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (16): Tanh()
#   )
# )
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (12): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2, inplace=True)
#     (14): Conv2d(1024, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (15): Sigmoid()
#   )
# )

# %% [markdown]
# Перейдем теперь к обучению нашего GANа. Алгоритм обучения следующий:
# 1. Учим дискриминатор:
#   * берем реальные изображения и присваиваем им метку 1
#   * генерируем изображения генератором и присваиваем им метку 0
#   * обучаем классификатор на два класса
#
# 2. Учим генератор:
#   * генерируем изображения генератором и присваиваем им метку 0
#   * предсказываем дискриминаторором, реальное это изображение или нет
#
#
# В качестве функции потерь берем бинарную кросс-энтропию

# %%
lr = 0.0001

model = {
    "discriminator": discriminator,
    "generator": generator
}

criterion = {
    "discriminator": nn.BCELoss(),
    "generator": nn.BCELoss()
}

# %%
def fit(model, criterion, dataloader, epochs, lr, latent_size=100, device='cuda'):
    # Инициализация моделей
    discriminator = model['discriminator'].to(device)
    generator = model['generator'].to(device)

    # Оптимизаторы
    optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))

    # Логирование
    losses_D = []
    losses_G = []

    # Фиксированный шум для визуализации прогресса
    fixed_noise = torch.randn(64, latent_size, 1, 1, device=device)

    for epoch in range(epochs):
        for i, (real_images) in enumerate(dataloader):
            batch_size = real_images.size(0)
            real_images = real_images.to(device)

            # Метки для реальных и фейковых изображений
            real_labels = torch.ones(batch_size, device=device)
            fake_labels = torch.zeros(batch_size, device=device)

            # ===================
            # 1. Обучение дискриминатора
            # ===================
            discriminator.zero_grad()

            # Ошибка на реальных изображениях
            outputs = discriminator(real_images)
            loss_D_real = criterion['discriminator'](outputs, real_labels)

            # Ошибка на фейковых изображениях
            noise = torch.randn(batch_size, latent_size, 1, 1, device=device)
            fake_images = generator(noise)
            outputs = discriminator(fake_images.detach())
            loss_D_fake = criterion['discriminator'](outputs, fake_labels)

            # Суммарная ошибка и обратное распространение
            loss_D = loss_D_real + loss_D_fake
            loss_D.backward()
            optimizer_D.step()

            # ===================
            # 2. Обучение генератора
            # ===================
            generator.zero_grad()

            # Генерируем изображения и пытаемся обмануть дискриминатор
            noise = torch.randn(batch_size, latent_size, 1, 1, device=device)
            fake_images = generator(noise)
            outputs = discriminator(fake_images)

            # Ошибка генератора - пытаемся убедить D что это реальные изображения
            loss_G = criterion['generator'](outputs, real_labels)
            loss_G.backward()
            optimizer_G.step()

            # Логирование
            losses_D.append(loss_D.item())
            losses_G.append(loss_G.item())

            if i % 100 == 0:
                print(f'Epoch [{epoch+1}/{epochs}], Batch [{i}/{len(dataloader)}], '
                      f'Loss D: {loss_D.item():.4f}, Loss G: {loss_G.item():.4f}')

        # Визуализация прогресса после каждой эпохи
        with torch.no_grad():
            fake = generator(fixed_noise).detach().cpu()
            # Добавьте здесь код для сохранения/отображения изображений

        # Сохранение моделей
        if (epoch+1) % 10 == 0:
            torch.save(generator.state_dict(), f'generator_epoch_{epoch+1}.pth')
            torch.save(discriminator.state_dict(), f'discriminator_epoch_{epoch+1}.pth')

    return losses_D, losses_G

# %%
lr = 0.0001
model = {
    "discriminator": Discriminator().to(device),
    "generator": Generator().to(device)
}
criterion = {
    "discriminator": nn.BCELoss(),
    "generator": nn.BCELoss()
}

# %%
epoch_num = 50
losses_D, losses_G = fit(model, criterion, dataloader, epoch_num, lr, latent_size=100, device=device)
# Out:
# Epoch [1/50], Batch [0/99], Loss D: 3.6221, Loss G: 6.2011
# Epoch [2/50], Batch [0/99], Loss D: 0.9136, Loss G: 7.5627
# Epoch [3/50], Batch [0/99], Loss D: 0.6198, Loss G: 7.7633
# Epoch [4/50], Batch [0/99], Loss D: 0.6158, Loss G: 9.3729
# Epoch [5/50], Batch [0/99], Loss D: 0.0674, Loss G: 6.9915
# Epoch [6/50], Batch [0/99], Loss D: 1.2723, Loss G: 14.4558
# Epoch [7/50], Batch [0/99], Loss D: 0.0558, Loss G: 4.6808
# Epoch [8/50], Batch [0/99], Loss D: 0.4588, Loss G: 8.2648
# Epoch [9/50], Batch [0/99], Loss D: 0.0481, Loss G: 5.6506
# Epoch [10/50], Batch [0/99], Loss D: 0.0685, Loss G: 5.5863
# Epoch [11/50], Batch [0/99], Loss D: 0.0582, Loss G: 6.4124
# Epoch [12/50], Batch [0/99], Loss D: 0.1516, Loss G: 6.6535
# Epoch [13/50], Batch [0/99], Loss D: 0.1049, Loss G: 5.9583
# Epoch [14/50], Batch [0/99], Loss D: 0.3174, Loss G: 2.1552
# Epoch [15/50], Batch [0/99], Loss D: 3.4959, Loss G: 18.3808
# Epoch [16/50], Batch [0/99], Loss D: 0.0793, Loss G: 4.4537
# Epoch [17/50], Batch [0/99], Loss D: 0.0599, Loss G: 4.8688
# Epoch [18/50], Batch [0/99], Loss D: 0.3790, Loss G: 7.5378
# Epoch [19/50], Batch [0/99], Loss D: 0.3358, Loss G: 7.4733
# Epoch [20/50], Batch [0/99], Loss D: 0.1796, Loss G: 5.4432
# Epoch [21/50], Batch [0/99], Loss D: 0.0595, Loss G: 6.6080
# Epoch [22/50], Batch [0/99], Loss D: 0.1982, Loss G: 5.6284
# Epoch [23/50], Batch [0/99], Loss D: 1.7129, Loss G: 14.6589
# Epoch [24/50], Batch [0/99], Loss D: 0.3061, Loss G: 9.6766
# Epoch [25/50], Batch [0/99], Loss D: 0.4234, Loss G: 10.4346
# Epoch [26/50], Batch [0/99], Loss D: 3.2193, Loss G: 19.5266
# Epoch [27/50], Batch [0/99], Loss D: 0.2207, Loss G: 5.7540
# Epoch [28/50], Batch [0/99], Loss D: 0.9185, Loss G: 11.3226
# Epoch [29/50], Batch [0/99], Loss D: 0.9691, Loss G: 11.9875
# Epoch [30/50], Batch [0/99], Loss D: 0.2044, Loss G: 7.6342
# Epoch [31/50], Batch [0/99], Loss D: 0.0575, Loss G: 5.9754
# Epoch [32/50], Batch [0/99], Loss D: 0.7040, Loss G: 8.2490
# Epoch [33/50], Batch [0/99], Loss D: 0.1828, Loss G: 5.9624
# Epoch [34/50], Batch [0/99], Loss D: 0.0630, Loss G: 6.3799
# Epoch [35/50], Batch [0/99], Loss D: 0.5270, Loss G: 5.2327
# Epoch [36/50], Batch [0/99], Loss D: 0.0238, Loss G: 6.0759
# Epoch [37/50], Batch [0/99], Loss D: 0.1014, Loss G: 5.2549
# Epoch [38/50], Batch [0/99], Loss D: 0.1573, Loss G: 5.9276
# Epoch [39/50], Batch [0/99], Loss D: 0.1066, Loss G: 5.5905
# Epoch [40/50], Batch [0/99], Loss D: 0.1642, Loss G: 7.2798
# Epoch [41/50], Batch [0/99], Loss D: 0.0561, Loss G: 7.1449
# Epoch [42/50], Batch [0/99], Loss D: 2.2525, Loss G: 14.0912
# Epoch [43/50], Batch [0/99], Loss D: 1.4849, Loss G: 16.3831
# Epoch [44/50], Batch [0/99], Loss D: 0.2178, Loss G: 8.5352
# Epoch [45/50], Batch [0/99], Loss D: 0.2373, Loss G: 8.5968
# Epoch [46/50], Batch [0/99], Loss D: 0.1680, Loss G: 5.9593
# Epoch [47/50], Batch [0/99], Loss D: 0.6210, Loss G: 11.3711
# Epoch [48/50], Batch [0/99], Loss D: 1.1136, Loss G: 10.7708
# Epoch [49/50], Batch [0/99], Loss D: 0.0565, Loss G: 4.0299
# Epoch [50/50], Batch [0/99], Loss D: 0.0107, Loss G: 7.1970

# %% [markdown]
# Постройте графики лосса для генератора и дискриминатора. Что вы можете сказать про эти графики?

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_gan_losses(history, smooth_window=10):
    """
    Визуализация лоссов генератора и дискриминатора
    :param history: словарь с лоссами {'D_losses': [...], 'G_losses': [...]}
    :param smooth_window: размер окна для скользящего среднего
    """
    plt.figure(figsize=(12, 6))

    # Сырые данные
    d_loss = np.array(history['D_losses'])
    g_loss = np.array(history['G_losses'])

    # Скользящее среднее для сглаживания
    def smooth(data, window):
        return np.convolve(data, np.ones(window)/window, mode='valid')

    d_smooth = smooth(d_loss, smooth_window)
    g_smooth = smooth(g_loss, smooth_window)

    # Графики
    plt.plot(d_loss, alpha=0.2, label='D Loss (raw)', color='blue')
    plt.plot(g_loss, alpha=0.2, label='G Loss (raw)', color='orange')
    plt.plot(d_smooth, label='D Loss (smooth)', color='blue', linewidth=2)
    plt.plot(g_smooth, label='G Loss (smooth)', color='orange', linewidth=2)

    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.title('GAN Training Losses')
    plt.legend()
    plt.grid(True)
    plt.show()

# Пример использования
history = {'D_losses':losses_D, 'G_losses':losses_G }
plot_gan_losses(history)

# %%
# 100 эпох
history = {'D_losses':losses_D, 'G_losses':losses_G }
plot_gan_losses(history)

# %% [markdown]
# ## Часть 3. Генерация изображений

# %% [markdown]
# Теперь давайте оценим качество получившихся изображений. Напишите функцию, которая выводит изображения, сгенерированные нашим генератором

# %%
def show_images(generated, nrow=None, figsize=(10, 10)):
    """
    Отображает сгенерированные изображения

    Параметры:
        generated (torch.Tensor): Тензор с изображениями (N, C, H, W)
        nrow (int): Количество изображений в строке. Если None - будет квадратная сетка
        figsize (tuple): Размер фигуры matplotlib
    """
    # Преобразуем тензор в numpy и меняем порядок измерений для matplotlib
    generated = generated.detach().cpu().numpy()
    generated = np.transpose(generated, (0, 2, 3, 1))

    # Нормализуем из [-1, 1] в [0, 1] (если использовался Tanh в генераторе)
    generated = (generated + 1) / 2
    generated = np.clip(generated, 0, 1)

    # Определяем параметры сетки
    n_images = generated.shape[0]
    if nrow is None:
        nrow = int(np.ceil(np.sqrt(n_images)))
    ncol = int(np.ceil(n_images / nrow))

    # Создаем фигуру
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize)
    if nrow == 1 and ncol == 1:
        axes = np.array([[axes]])
    elif nrow == 1 or ncol == 1:
        axes = axes.reshape(nrow, ncol)

    # Отображаем изображения
    for i in range(nrow):
        for j in range(ncol):
            idx = i * ncol + j
            if idx < n_images:
                axes[i,j].imshow(generated[idx])
            axes[i,j].axis('off')

    plt.tight_layout()
    plt.show()

# %%
# Пример использования
fixed_latent = torch.randn(20, 100, 1, 1, device=device)
fake_images = model["generator"](fixed_latent)
show_images(fake_images, nrow=5)

# %%
# Пример использования
fixed_latent = torch.randn(20, 100, 1, 1, device=device)
fake_images = model["generator"](fixed_latent)
show_images(fake_images, nrow=5)

# %%
n_images = 4

fixed_latent = torch.randn(n_images, latent_size, 1, 1, device=device)
fake_images = model["generator"](fixed_latent)

# %%
def show_images(generated):
  # TODO: show generated images
  pass

# %% [markdown]
# Как вам качество получившихся изображений?

# %% [markdown]
# ## Часть 4. Leave-one-out-1-NN classifier accuracy (6 баллов)

# %% [markdown]
# ### 4.1. Подсчет accuracy (1.5 балл)

# %% [markdown]
# Не всегда бывает удобно оценивать качество сгенерированных картинок глазами. В качестве альтернативы вам предлагается реализовать следующий подход:
#   * Сгенерировать столько же фейковых изображений, сколько есть настоящих в обучающей выборке. Присвоить фейковым метку класса 0, настоящим – 1.
#   * Построить leave-one-out оценку: обучить 1NN Classifier (`sklearn.neighbors.KNeighborsClassifier(n_neighbors=1)`) предсказывать класс на всех объектах, кроме одного, проверить качество (accuracy) на оставшемся объекте. В этом вам поможет `sklearn.model_selection.LeaveOneOut`

# %%
real_dataloader = get_dataloader(2)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np



# 2. Инициализируем генератор (как у вас в коде)
# generator = Generator()
# generator.eval()  # Важно для отключения dropout/batchnorm

# 3. Создаем DataLoader для "реальных" данных

# 4. Определяем MixedDataset (ваш класс, но с добавлением device)
class MixedDataset(Dataset):
    def __init__(self, real_dataloader, generator, num_real_samples, device="cpu"):
        self.device = device
        self.generator = generator.to(device)
        self.generator.eval()

        # Загружаем все реальные изображения
        self.real_images = []
        for batch in real_dataloader:
            self.real_images.append(batch)
        self.real_images = torch.cat(self.real_images, dim=0)

        # Генерируем фейковые изображения
        with torch.no_grad():
            noise = torch.randn(num_real_samples, latent_size, 1, 1, device=device)
            self.fake_images = generator(noise).cpu()

        # Метки: 0 для фейков, 1 для реальных
        self.labels = torch.cat([
            torch.zeros(len(self.fake_images)),
            torch.ones(len(self.real_images))
        ])

        # Объединяем все изображения
        self.all_images = torch.cat([self.fake_images, self.real_images], dim=0)

    def __len__(self):
        return len(self.all_images)

    def __getitem__(self, idx):
        return self.all_images[idx], self.labels[idx]

# 5. Тестируем MixedDataset
# mixed_dataset = MixedDataset(real_dataloader, generator, num_real_samples=5, device="cpu")
# print(f"Общий размер датасета: {len(mixed_dataset)}")  # Должно быть 10 (5 фейков + 5 реальных)

# %%
# Пусть real_dataloader уже загружен с 3100 изображениями (128x128)
print(f"Количество реальных изображений: {len(real_dataloader.dataset)}")  # Должно быть 3100

# Инициализация генератора (как в вашем коде)
generator = model["generator"]
generator.eval()  # Отключаем dropout/batchnorm

# Создаем MixedDataset
mixed_dataset = MixedDataset(
    real_dataloader=real_dataloader,
    generator=generator,
    num_real_samples=len(real_dataloader.dataset),  # 3100 фейков
    device="cuda" if torch.cuda.is_available() else "cpu"
)

# Проверяем размер
print(f"Общий размер датасета: {len(mixed_dataset)}")  # Должно быть 6200 (3100 фейков + 3100 реальных)
# Out:
# Количество реальных изображений: 3143
# Общий размер датасета: 6286

# %%
def plot_images(dataset, num_samples=4):
    fig, axes = plt.subplots(1, num_samples, figsize=(15, 3))
    indices = np.random.choice(len(dataset), num_samples, replace=False)
    for i, idx in enumerate(indices):
        img, label = dataset[idx]
        img = img.permute(1, 2, 0).numpy()  # CHW -> HWC
        img = (img - img.min()) / (img.max() - img.min())  # Нормализация [0, 1]
        axes[i].imshow(img)
        axes[i].set_title(f"Label: {int(label)} ({'Фейк' if label == 0 else 'Реальное'})")
        axes[i].axis("off")
    plt.show()

plot_images(mixed_dataset)

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import LeaveOneOut
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# 1. Преобразуем mixed_dataset в numpy массивы
X = []
y = []
for i in range(len(mixed_dataset)):
    img, label = mixed_dataset[i]
    X.append(img.flatten().numpy())  # Преобразуем изображение в вектор (128*128*3)
    y.append(label.item())  # Метка (0 или 1)

X = np.array(X)  # Размер: (n_samples, 128*128*3)
y = np.array(y)  # Размер: (n_samples,)

# %%
# 2. Нормализация данных (рекомендуется для KNN)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 3. Инициализация 1NN и LOO
knn = KNeighborsClassifier(n_neighbors=1)
loo = LeaveOneOut()

# %%
len(list(loo.split(X_scaled)))
# Out:
# 6286

# %%
len(X_scaled[0])
# Out:
# 49152

# %%
X_scaled = X_scaled[:1000]
y = y[:1000]

# %%
# 4. Вычисление LOO accuracy
y_true = []
y_pred = []

for train_idx, test_idx in loo.split(X_scaled):
    X_train, X_test = X_scaled[train_idx], X_scaled[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    knn.fit(X_train, y_train)
    pred = knn.predict(X_test)

    y_true.append(y_test[0])
    y_pred.append(pred[0])

accuracy = accuracy_score(y_true, y_pred)
print(f"Leave-One-Out Accuracy: {accuracy:.4f}")
# Out:
# Leave-One-Out Accuracy: 1.0000

# %% [markdown]
# Что вы можете сказать о получившемся результате? Какой accuracy мы хотели бы получить и почему?

# %% [markdown]
# ### 4.2. Визуализация распределений (1 балл)

# %% [markdown]
# Давайте посмотрим на то, насколько похожи распределения настоящих и фейковых изображений. Для этого воспользуйтесь методом, снижающим размерность (к примеру, TSNE) и изобразите на графике разным цветом точки, соответствующие реальным и сгенерированным изображенияи

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 1. Подготовка данных
X = []
y = []
for i in range(len(mixed_dataset)):
    img, label = mixed_dataset[i]
    X.append(img.flatten().numpy())  # (3*128*128,)
    y.append(label.item())  # 0 (фейк) или 1 (реальное)

X = np.array(X)  # (n_samples, 49152)
y = np.array(y)  # (n_samples,)

# %%
# 2. Уменьшение размерности (чтобы ускорить t-SNE)
pca = PCA(n_components=50)  # Сначала сжимаем до 50 компонент
X_pca = pca.fit_transform(X)

# %%
# 3. Применяем t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)
X_tsne = tsne.fit_transform(X_pca)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
# 4. Визуализация
plt.figure(figsize=(10, 8))
plt.scatter(X_tsne[y == 0, 0], X_tsne[y == 0, 1], c='red', label='Фейки (0)', alpha=0.6)
plt.scatter(X_tsne[y == 1, 0], X_tsne[y == 1, 1], c='blue', label='Реальные (1)', alpha=0.6)
plt.title('t-SNE: Распределение настоящих и фейковых изображений')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 4. Визуализация
plt.figure(figsize=(10, 8))
plt.scatter(X_tsne[y == 0, 0], X_tsne[y == 0, 1], c='red', label='Фейки (0)', alpha=0.6)
plt.scatter(X_tsne[y == 1, 0], X_tsne[y == 1, 1], c='blue', label='Реальные (1)', alpha=0.6)
plt.title('t-SNE: Распределение настоящих и фейковых изображений')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Прокомментируйте получившийся результат:
